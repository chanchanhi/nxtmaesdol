# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

def precise_error_edge_detection(gray_image):
    sobelx = cv2.Sobel(gray_image, cv2.CV_64F, 1, 0, ksize=3)
    sobely = cv2.Sobel(gray_image, cv2.CV_64F, 0, 1, ksize=3)
    
    magnitude = np.sqrt(sobelx**2 + sobely**2)
    
    threshold = np.mean(magnitude) + 2 * np.std(magnitude)
    binary_edges = (magnitude > threshold).astype(np.uint8) * 255
    
    return binary_edges

def preprocess_image(image):
    # 1. Grayscale 변환
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    # 2. Gaussian Blur (노이즈 감소)
    blurred = cv2.GaussianBlur(gray, (7, 7), 1)
    
    # 3. Bilateral Filter (엣지 보존)
    filtered = cv2.bilateralFilter(blurred, 20, 90, 130)
    
    # 4. CLAHE (대비 개선)
    clahe = cv2.createCLAHE(clipLimit=4.0, tileGridSize=(4, 4))
    enhanced = clahe.apply(filtered)
    
    # 5. Precise Error Edge Detection
    edges = precise_error_edge_detection(enhanced)
    return edges

def process_and_save_images(input_folder, output_folder):
    # 출력 폴더 생성
    Path(output_folder).mkdir(parents=True, exist_ok=True)
    
    # BMP 파일 목록 가져오기
    image_files = [f for f in os.listdir(input_folder) if f.lower().endswith('.bmp')]
    
    print(f"총 처리할 이미지 개수: {len(image_files)}")
    
    for i, filename in enumerate(image_files, 1):
        input_path = os.path.join(input_folder, filename)
        image = cv2.imread(input_path)
        
        if image is not None:
            # 이미지 전처리
            edges = preprocess_image(image)
            
            # 최종 결과 저장
            output_path = os.path.join(output_folder, f'edge_{filename}')
            cv2.imwrite(output_path, edges)
            
            # 진행 상태 출력
            print(f"[{i}/{len(image_files)}] 처리완료: {filename}")
        else:
            print(f"[!] 에러: {filename} 파일을 읽을 수 없습니다.")
    
    print("모든 이미지 처리가 완료되었습니다.")

# 실행 코드
input_folder = '/home/ec2-user/SageMaker/data/Final_Data/OK/'
output_folder = '/home/ec2-user/SageMaker/data/Final_Data/OK_processed_v2/'

# 이미지 처리 및 저장
processed_images = process_and_save_images(input_folder, output_folder)
# Out:
# 총 처리할 이미지 개수: 4386
# [1/4386] 처리완료: 1701.bmp
# [2/4386] 처리완료: 1464.bmp
# [3/4386] 처리완료: 1529.bmp
# [4/4386] 처리완료: 4428.bmp
# [5/4386] 처리완료: 3931.bmp
# [6/4386] 처리완료: 1397.bmp
# [7/4386] 처리완료: 4897.bmp
# [8/4386] 처리완료: 1158.bmp
# [9/4386] 처리완료: 4668.bmp
# [10/4386] 처리완료: 3496.bmp
# [11/4386] 처리완료: 563.bmp
# [12/4386] 처리완료: 4140.bmp
# [13/4386] 처리완료: 1641.bmp
# [14/4386] 처리완료: 614.bmp
# [15/4386] 처리완료: 3421.bmp
# [16/4386] 처리완료: 4173.bmp
# [17/4386] 처리완료: 396.bmp
# [18/4386] 처리완료: 1637.bmp
# [19/4386] 처리완료: 3352.bmp
# [20/4386] 처리완료: 4030.bmp
# [21/4386] 처리완료: 4762.bmp
# [22/4386] 처리완료: 3552.bmp
# [23/4386] 처리완료: 3807.bmp
# [24/4386] 처리완료: 4689.bmp
# [25/4386] 처리완료: 3248.bmp
# [26/4386] 처리완료: 885.bmp
# [27/4386] 처리완료: 2081.bmp
# [28/4386] 처리완료: 2799.bmp
# [29/4386] 처리완료: 4949.bmp
# [30/4386] 처리완료: 273.bmp
# [31/4386] 처리완료: 1794.bmp
# [32/4386] 처리완료: 4208.bmp
# [33/4386] 처리완료: 4437.bmp
# [34/4386] 처리완료: 3120.bmp
# [35/4386] 처리완료: 3810.bmp
# [36/4386] 처리완료: 3761.bmp
# [37/4386] 처리완료: 4712.bmp
# [38/4386] 처리완료: 2300.bmp
# [39/4386] 처리완료: 167.bmp
# [40/4386] 처리완료: 1989.bmp
# [41/4386] 처리완료: 4065.bmp
# [42/4386] 처리완료: 153.bmp
# [43/4386] 처리완료: 2426.bmp
# [44/4386] 처리완료: 714.bmp
# [45/4386] 처리완료: 1676.bmp
# [46/4386] 처리완료: 4475.bmp
# [47/4386] 처리완료: 3495.bmp
# [48/4386] 처리완료: 3271.bmp
# [49/4386] 처리완료: 4323.bmp
# [50/4386] 처리완료: 1037.bmp
# [51/4386] 처리완료: 1473.bmp
# [52/4386] 처리완료: 1349.bmp
# [53/4386] 처리완료: 380.bmp
# [54/4386] 처리완료: 2325.bmp
# [55/4386] 처리완료: 1344.bmp
# [56/4386] 처리완료: 4418.bmp
# [57/4386] 처리완료: 1522.bmp
# [58/4386] 처리완료: 4906.bmp
# [59/4386] 처리완료: 2696.bmp
# [60/4386] 처리완료: 2648.bmp
# [61/4386] 처리완료: 70.bmp
# [62/4386] 처리완료: 3221.bmp
# [63/4386] 처리완료: 2169.bmp
# [64/4386] 처리완료: 2477.bmp
# [65/4386] 처리완료: 55.bmp
# [66/4386] 처리완료: 617.bmp
# [67/4386] 처리완료: 1908.bmp
# [68/4386] 처리완료: 4458.bmp
# [69/4386] 처리완료: 3445.bmp
# [70/4386] 처리완료: 505.bmp
# [71/4386] 처리완료: 1334.bmp
# [72/4386] 처리완료: 3434.bmp
# [73/4386] 처리완료: 5034.bmp
# [74/4386] 처리완료: 430.bmp
# [75/4386] 처리완료: 5060.bmp
# [76/4386] 처리완료: 2600.bmp
# [77/4386] 처리완료: 1730.bmp
# [78/4386] 처리완료: 2161.bmp
# [79/4386] 처리완료: 2380.bmp
# [80/4386] 처리완료: 3009.bmp
# [81/4386] 처리완료: 4517.bmp
# [82/4386] 처리완료: 584.bmp
# [83/4386] 처리완료: 186.bmp
# [84/4386] 처리완료: 30.bmp
# [85/4386] 처리완료: 1925.bmp
# [86/4386] 처리완료: 3335.bmp
# [87/4386] 처리완료: 1124.bmp
# [88/4386] 처리완료: 3374.bmp
# [89/4386] 처리완료: 249.bmp
# [90/4386] 처리완료: 2479.bmp
# [91/4386] 처리완료: 3483.bmp
# [92/4386] 처리완료: 4125.bmp
# [93/4386] 처리완료: 3663.bmp
# [94/4386] 처리완료: 182.bmp
# [95/4386] 처리완료: 3341.bmp
# [96/4386] 처리완료: 753.bmp
# [97/4386] 처리완료: 2587.bmp
# [98/4386] 처리완료: 794.bmp
# [99/4386] 처리완료: 763.bmp
# [100/4386] 처리완료: 1402.bmp
# [101/4386] 처리완료: 2359.bmp
# [102/4386] 처리완료: 1313.bmp
# [103/4386] 처리완료: 3382.bmp
# [104/4386] 처리완료: 3367.bmp
# [105/4386] 처리완료: 319.bmp
# [106/4386] 처리완료: 1425.bmp
# [107/4386] 처리완료: 3086.bmp
# [108/4386] 처리완료: 2197.bmp
# [109/4386] 처리완료: 3200.bmp
# [110/4386] 처리완료: 2251.bmp
# [111/4386] 처리완료: 3285.bmp
# [112/4386] 처리완료: 1225.bmp
# [113/4386] 처리완료: 1836.bmp
# [114/4386] 처리완료: 3643.bmp
# [115/4386] 처리완료: 4957.bmp
# [116/4386] 처리완료: 2690.bmp
# [117/4386] 처리완료: 2705.bmp
# [118/4386] 처리완료: 3745.bmp
# [119/4386] 처리완료: 648.bmp
# [120/4386] 처리완료: 3784.bmp
# [121/4386] 처리완료: 2677.bmp
# [122/4386] 처리완료: 2839.bmp
# [123/4386] 처리완료: 2165.bmp
# [124/4386] 처리완료: 3425.bmp
# [125/4386] 처리완료: 1191.bmp
# [126/4386] 처리완료: 1638.bmp
# [127/4386] 처리완료: 1850.bmp
# [128/4386] 처리완료: 569.bmp
# [129/4386] 처리완료: 3480.bmp
# [130/4386] 처리완료: 1286.bmp
# [131/4386] 처리완료: 4607.bmp
# [132/4386] 처리완료: 3322.bmp
# [133/4386] 처리완료: 2936.bmp
# [134/4386] 처리완료: 3209.bmp
# [135/4386] 처리완료: 3168.bmp
# [136/4386] 처리완료: 4186.bmp
# [137/4386] 처리완료: 3455.bmp
# [138/4386] 처리완료: 3686.bmp
# [139/4386] 처리완료: 3361.bmp
# [140/4386] 처리완료: 4640.bmp
# [141/4386] 처리완료: 4479.bmp
# [142/4386] 처리완료: 1580.bmp
# [143/4386] 처리완료: 780.bmp
# [144/4386] 처리완료: 4467.bmp
# [145/4386] 처리완료: 2102.bmp
# [146/4386] 처리완료: 2024.bmp
# [147/4386] 처리완료: 150.bmp
# [148/4386] 처리완료: 2661.bmp
# [149/4386] 처리완료: 2657.bmp
# [150/4386] 처리완료: 2946.bmp
# [151/4386] 처리완료: 4023.bmp
# [152/4386] 처리완료: 2120.bmp
# [153/4386] 처리완료: 2952.bmp
# [154/4386] 처리완료: 3255.bmp
# [155/4386] 처리완료: 1902.bmp
# [156/4386] 처리완료: 4480.bmp
# [157/4386] 처리완료: 3390.bmp
# [158/4386] 처리완료: 4705.bmp
# [159/4386] 처리완료: 3748.bmp
# [160/4386] 처리완료: 161.bmp
# [161/4386] 처리완료: 473.bmp
# [162/4386] 처리완료: 2230.bmp
# [163/4386] 처리완료: 5056.bmp
# [164/4386] 처리완료: 4136.bmp
# [165/4386] 처리완료: 822.bmp
# [166/4386] 처리완료: 1240.bmp
# [167/4386] 처리완료: 879.bmp
# [168/4386] 처리완료: 259.bmp
# [169/4386] 처리완료: 2797.bmp
# [170/4386] 처리완료: 478.bmp
# [171/4386] 처리완료: 4426.bmp
# [172/4386] 처리완료: 5016.bmp
# [173/4386] 처리완료: 3183.bmp
# [174/4386] 처리완료: 4113.bmp
# [175/4386] 처리완료: 1145.bmp
# [176/4386] 처리완료: 4052.bmp
# [177/4386] 처리완료: 1337.bmp
# [178/4386] 처리완료: 3758.bmp
# [179/4386] 처리완료: 4156.bmp
# [180/4386] 처리완료: 2792.bmp
# [181/4386] 처리완료: 4067.bmp
# [182/4386] 처리완료: 3484.bmp
# [183/4386] 처리완료: 193.bmp
# [184/4386] 처리완료: 4221.bmp
# [185/4386] 처리완료: 1700.bmp
# [186/4386] 처리완료: 3640.bmp
# [187/4386] 처리완료: 3498.bmp
# [188/4386] 처리완료: 4503.bmp
# [189/4386] 처리완료: 119.bmp
# [190/4386] 처리완료: 590.bmp
# [191/4386] 처리완료: 4504.bmp
# [192/4386] 처리완료: 4671.bmp
# [193/4386] 처리완료: 698.bmp
# [194/4386] 처리완료: 4149.bmp
# [195/4386] 처리완료: 1714.bmp
# [196/4386] 처리완료: 5008.bmp
# [197/4386] 처리완료: 4252.bmp
# [198/4386] 처리완료: 5068.bmp
# [199/4386] 처리완료: 4093.bmp
# [200/4386] 처리완료: 2221.bmp
# [201/4386] 처리완료: 2752.bmp
# [202/4386] 처리완료: 1137.bmp
# [203/4386] 처리완료: 50.bmp
# [204/4386] 처리완료: 3437.bmp
# [205/4386] 처리완료: 2686.bmp
# [206/4386] 처리완료: 2601.bmp
# [207/4386] 처리완료: 684.bmp
# [208/4386] 처리완료: 2493.bmp
# [209/4386] 처리완료: 4139.bmp
# [210/4386] 처리완료: 3297.bmp
# [211/4386] 처리완료: 46.bmp
# [212/4386] 처리완료: 3077.bmp
# [213/4386] 처리완료: 4621.bmp
# [214/4386] 처리완료: 672.bmp
# [215/4386] 처리완료: 2746.bmp
# [216/4386] 처리완료: 3318.bmp
# [217/4386] 처리완료: 2345.bmp
# [218/4386] 처리완료: 4805.bmp
# [219/4386] 처리완료: 4254.bmp
# [220/4386] 처리완료: 4195.bmp
# [221/4386] 처리완료: 612.bmp
# [222/4386] 처리완료: 1834.bmp
# [223/4386] 처리완료: 405.bmp
# [224/4386] 처리완료: 661.bmp
# [225/4386] 처리완료: 3443.bmp
# [226/4386] 처리완료: 3198.bmp
# [227/4386] 처리완료: 3926.bmp
# [228/4386] 처리완료: 3883.bmp
# [229/4386] 처리완료: 2075.bmp
# [230/4386] 처리완료: 4884.bmp
# [231/4386] 처리완료: 1663.bmp
# [232/4386] 처리완료: 4307.bmp
# [233/4386] 처리완료: 4961.bmp
# [234/4386] 처리완료: 3683.bmp
# [235/4386] 처리완료: 232.bmp
# [236/4386] 처리완료: 4701.bmp
# [237/4386] 처리완료: 3351.bmp
# [238/4386] 처리완료: 1652.bmp
# [239/4386] 처리완료: 3112.bmp
# [240/4386] 처리완료: 242.bmp
# [241/4386] 처리완료: 2700.bmp
# [242/4386] 처리완료: 1781.bmp
# [243/4386] 처리완료: 305.bmp
# [244/4386] 처리완료: 3353.bmp
# [245/4386] 처리완료: 3162.bmp
# [246/4386] 처리완료: 289.bmp
# [247/4386] 처리완료: 2160.bmp
# [248/4386] 처리완료: 4203.bmp
# [249/4386] 처리완료: 143.bmp
# [250/4386] 처리완료: 3865.bmp
# [251/4386] 처리완료: 3036.bmp
# [252/4386] 처리완료: 3058.bmp
# [253/4386] 처리완료: 3893.bmp
# [254/4386] 처리완료: 660.bmp
# [255/4386] 처리완료: 3109.bmp
# [256/4386] 처리완료: 302.bmp
# [257/4386] 처리완료: 2463.bmp
# [258/4386] 처리완료: 3523.bmp
# [259/4386] 처리완료: 1361.bmp
# [260/4386] 처리완료: 1514.bmp
# [261/4386] 처리완료: 1345.bmp
# [262/4386] 처리완료: 840.bmp
# [263/4386] 처리완료: 4818.bmp
# [264/4386] 처리완료: 4846.bmp
# [265/4386] 처리완료: 1398.bmp
# [266/4386] 처리완료: 3984.bmp
# [267/4386] 처리완료: 2158.bmp
# [268/4386] 처리완료: 4240.bmp
# [269/4386] 처리완료: 2581.bmp
# [270/4386] 처리완료: 2137.bmp
# [271/4386] 처리완료: 1945.bmp
# [272/4386] 처리완료: 2269.bmp
# [273/4386] 처리완료: 3597.bmp
# [274/4386] 처리완료: 2428.bmp
# [275/4386] 처리완료: 4862.bmp
# [276/4386] 처리완료: 3543.bmp
# [277/4386] 처리완료: 2095.bmp
# [278/4386] 처리완료: 181.bmp
# [279/4386] 처리완료: 178.bmp
# [280/4386] 처리완료: 4744.bmp
# [281/4386] 처리완료: 668.bmp
# [282/4386] 처리완료: 1465.bmp
# [283/4386] 처리완료: 183.bmp
# [284/4386] 처리완료: 202.bmp
# [285/4386] 처리완료: 2536.bmp
# [286/4386] 처리완료: 341.bmp
# [287/4386] 처리완료: 4874.bmp
# [288/4386] 처리완료: 3691.bmp
# [289/4386] 처리완료: 3799.bmp
# [290/4386] 처리완료: 4543.bmp
# [291/4386] 처리완료: 5061.bmp
# [292/4386] 처리완료: 4870.bmp
# [293/4386] 처리완료: 812.bmp
# [294/4386] 처리완료: 3034.bmp
# [295/4386] 처리완료: 1434.bmp
# [296/4386] 처리완료: 4333.bmp
# [297/4386] 처리완료: 4854.bmp
# [298/4386] 처리완료: 582.bmp
# [299/4386] 처리완료: 3407.bmp
# [300/4386] 처리완료: 3056.bmp
# [301/4386] 처리완료: 2330.bmp
# [302/4386] 처리완료: 2583.bmp
# [303/4386] 처리완료: 5032.bmp
# [304/4386] 처리완료: 3646.bmp
# [305/4386] 처리완료: 1807.bmp
# [306/4386] 처리완료: 2780.bmp
# [307/4386] 처리완료: 1871.bmp
# [308/4386] 처리완료: 4696.bmp
# [309/4386] 처리완료: 4449.bmp
# [310/4386] 처리완료: 142.bmp
# [311/4386] 처리완료: 531.bmp
# [312/4386] 처리완료: 2764.bmp
# [313/4386] 처리완료: 4849.bmp
# [314/4386] 처리완료: 1444.bmp
# [315/4386] 처리완료: 3272.bmp
# [316/4386] 처리완료: 1724.bmp
# [317/4386] 처리완료: 4440.bmp
# [318/4386] 처리완료: 2149.bmp
# [319/4386] 처리완료: 77.bmp
# [320/4386] 처리완료: 5081.bmp
# [321/4386] 처리완료: 4285.bmp
# [322/4386] 처리완료: 3326.bmp
# [323/4386] 처리완료: 4038.bmp
# [324/4386] 처리완료: 2005.bmp
# [325/4386] 처리완료: 2516.bmp
# [326/4386] 처리완료: 1543.bmp
# [327/4386] 처리완료: 224.bmp
# [328/4386] 처리완료: 2440.bmp
# [329/4386] 처리완료: 4637.bmp
# [330/4386] 처리완료: 4537.bmp
# [331/4386] 처리완료: 574.bmp
# [332/4386] 처리완료: 632.bmp
# [333/4386] 처리완료: 2082.bmp
# [334/4386] 처리완료: 5091.bmp
# [335/4386] 처리완료: 4774.bmp
# [336/4386] 처리완료: 4639.bmp
# [337/4386] 처리완료: 2751.bmp
# [338/4386] 처리완료: 1438.bmp
# [339/4386] 처리완료: 3992.bmp
# [340/4386] 처리완료: 3855.bmp
# [341/4386] 처리완료: 1462.bmp
# [342/4386] 처리완료: 1972.bmp
# [343/4386] 처리완료: 4210.bmp
# [344/4386] 처리완료: 1518.bmp
# [345/4386] 처리완료: 597.bmp
# [346/4386] 처리완료: 551.bmp
# [347/4386] 처리완료: 376.bmp
# [348/4386] 처리완료: 4147.bmp
# [349/4386] 처리완료: 2277.bmp
# [350/4386] 처리완료: 905.bmp
# [351/4386] 처리완료: 1376.bmp
# [352/4386] 처리완료: 1086.bmp
# [353/4386] 처리완료: 65.bmp
# [354/4386] 처리완료: 3055.bmp
# [355/4386] 처리완료: 4468.bmp
# [356/4386] 처리완료: 4616.bmp
# [357/4386] 처리완료: 2638.bmp
# [358/4386] 처리완료: 4405.bmp
# [359/4386] 처리완료: 4583.bmp
# [360/4386] 처리완료: 5085.bmp
# [361/4386] 처리완료: 5076.bmp
# [362/4386] 처리완료: 92.bmp
# [363/4386] 처리완료: 128.bmp
# [364/4386] 처리완료: 1290.bmp
# [365/4386] 처리완료: 176.bmp
# [366/4386] 처리완료: 4050.bmp
# [367/4386] 처리완료: 2154.bmp
# [368/4386] 처리완료: 717.bmp
# [369/4386] 처리완료: 2770.bmp
# [370/4386] 처리완료: 164.bmp
# [371/4386] 처리완료: 2215.bmp
# [372/4386] 처리완료: 2.bmp
# [373/4386] 처리완료: 2905.bmp
# [374/4386] 처리완료: 4004.bmp
# [375/4386] 처리완료: 3181.bmp
# [376/4386] 처리완료: 1374.bmp
# [377/4386] 처리완료: 4655.bmp
# [378/4386] 처리완료: 4823.bmp
# [379/4386] 처리완료: 1105.bmp
# [380/4386] 처리완료: 3746.bmp
# [381/4386] 처리완료: 3306.bmp
# [382/4386] 처리완료: 999.bmp
# [383/4386] 처리완료: 1998.bmp
# [384/4386] 처리완료: 124.bmp
# [385/4386] 처리완료: 4434.bmp
# [386/4386] 처리완료: 2376.bmp
# [387/4386] 처리완료: 1801.bmp
# [388/4386] 처리완료: 630.bmp
# [389/4386] 처리완료: 1607.bmp
# [390/4386] 처리완료: 1681.bmp
# [391/4386] 처리완료: 1490.bmp
# [392/4386] 처리완료: 284.bmp
# [393/4386] 처리완료: 3144.bmp
# [394/4386] 처리완료: 2332.bmp
# [395/4386] 처리완료: 1212.bmp
# [396/4386] 처리완료: 4145.bmp
# [397/4386] 처리완료: 1711.bmp
# [398/4386] 처리완료: 1016.bmp
# [399/4386] 처리완료: 1497.bmp
# [400/4386] 처리완료: 1880.bmp
# [401/4386] 처리완료: 2270.bmp
# [402/4386] 처리완료: 2419.bmp
# [403/4386] 처리완료: 3653.bmp
# [404/4386] 처리완료: 95.bmp
# [405/4386] 처리완료: 4420.bmp
# [406/4386] 처리완료: 2538.bmp
# [407/4386] 처리완료: 1226.bmp
# [408/4386] 처리완료: 2236.bmp
# [409/4386] 처리완료: 2080.bmp
# [410/4386] 처리완료: 3303.bmp
# [411/4386] 처리완료: 3966.bmp
# [412/4386] 처리완료: 2729.bmp
# [413/4386] 처리완료: 4983.bmp
# [414/4386] 처리완료: 2786.bmp
# [415/4386] 처리완료: 1126.bmp
# [416/4386] 처리완료: 492.bmp
# [417/4386] 처리완료: 2086.bmp
# [418/4386] 처리완료: 1668.bmp
# [419/4386] 처리완료: 3007.bmp
# [420/4386] 처리완료: 3714.bmp
# [421/4386] 처리완료: 4393.bmp
# [422/4386] 처리완료: 340.bmp
# [423/4386] 처리완료: 4120.bmp
# [424/4386] 처리완료: 3769.bmp
# [425/4386] 처리완료: 432.bmp
# [426/4386] 처리완료: 3088.bmp
# [427/4386] 처리완료: 3223.bmp
# [428/4386] 처리완료: 2576.bmp
# [429/4386] 처리완료: 48.bmp
# [430/4386] 처리완료: 4969.bmp
# [431/4386] 처리완료: 866.bmp
# [432/4386] 처리완료: 4903.bmp
# [433/4386] 처리완료: 2961.bmp
# [434/4386] 처리완료: 3145.bmp
# [435/4386] 처리완료: 1249.bmp
# [436/4386] 처리완료: 4414.bmp
# [437/4386] 처리완료: 39.bmp
# [438/4386] 처리완료: 2916.bmp
# [439/4386] 처리완료: 4551.bmp
# [440/4386] 처리완료: 278.bmp
# [441/4386] 처리완료: 4075.bmp
# [442/4386] 처리완료: 1111.bmp
# [443/4386] 처리완료: 2498.bmp
# [444/4386] 처리완료: 909.bmp
# [445/4386] 처리완료: 4459.bmp
# [446/4386] 처리완료: 2567.bmp
# [447/4386] 처리완료: 1921.bmp
# [448/4386] 처리완료: 710.bmp
# [449/4386] 처리완료: 4166.bmp
# [450/4386] 처리완료: 1446.bmp
# [451/4386] 처리완료: 649.bmp
# [452/4386] 처리완료: 3448.bmp
# [453/4386] 처리완료: 2877.bmp
# [454/4386] 처리완료: 3487.bmp
# [455/4386] 처리완료: 1089.bmp
# [456/4386] 처리완료: 3845.bmp
# [457/4386] 처리완료: 941.bmp
# [458/4386] 처리완료: 884.bmp
# [459/4386] 처리완료: 3779.bmp
# [460/4386] 처리완료: 216.bmp
# [461/4386] 처리완료: 3879.bmp
# [462/4386] 처리완료: 89.bmp
# [463/4386] 처리완료: 4146.bmp
# [464/4386] 처리완료: 239.bmp
# [465/4386] 처리완료: 520.bmp
# [466/4386] 처리완료: 3741.bmp
# [467/4386] 처리완료: 529.bmp
# [468/4386] 처리완료: 1614.bmp
# [469/4386] 처리완료: 158.bmp
# [470/4386] 처리완료: 3720.bmp
# [471/4386] 처리완료: 4651.bmp
# [472/4386] 처리완료: 3698.bmp
# [473/4386] 처리완료: 3290.bmp
# [474/4386] 처리완료: 2866.bmp
# [475/4386] 처리완료: 3717.bmp
# [476/4386] 처리완료: 4217.bmp
# [477/4386] 처리완료: 4214.bmp
# [478/4386] 처리완료: 4881.bmp
# [479/4386] 처리완료: 3689.bmp
# [480/4386] 처리완료: 922.bmp
# [481/4386] 처리완료: 2209.bmp
# [482/4386] 처리완료: 3994.bmp
# [483/4386] 처리완료: 112.bmp
# [484/4386] 처리완료: 2639.bmp
# [485/4386] 처리완료: 2745.bmp
# [486/4386] 처리완료: 3542.bmp
# [487/4386] 처리완료: 1127.bmp
# [488/4386] 처리완료: 2218.bmp
# [489/4386] 처리완료: 4943.bmp
# [490/4386] 처리완료: 1745.bmp
# [491/4386] 처리완료: 2681.bmp
# [492/4386] 처리완료: 952.bmp
# [493/4386] 처리완료: 399.bmp
# [494/4386] 처리완료: 4964.bmp
# [495/4386] 처리완료: 3249.bmp
# [496/4386] 처리완료: 2368.bmp
# [497/4386] 처리완료: 3243.bmp
# [498/4386] 처리완료: 892.bmp
# [499/4386] 처리완료: 3703.bmp
# [500/4386] 처리완료: 1280.bmp
# [501/4386] 처리완료: 2925.bmp
# [502/4386] 처리완료: 3593.bmp
# [503/4386] 처리완료: 3039.bmp
# [504/4386] 처리완료: 1644.bmp
# [505/4386] 처리완료: 3782.bmp
# [506/4386] 처리완료: 517.bmp
# [507/4386] 처리완료: 392.bmp
# [508/4386] 처리완료: 3203.bmp
# [509/4386] 처리완료: 1984.bmp
# [510/4386] 처리완료: 2361.bmp
# [511/4386] 처리완료: 1726.bmp
# [512/4386] 처리완료: 1593.bmp
# [513/4386] 처리완료: 4473.bmp
# [514/4386] 처리완료: 4255.bmp
# [515/4386] 처리완료: 4806.bmp
# [516/4386] 처리완료: 4938.bmp
# [517/4386] 처리완료: 1047.bmp
# [518/4386] 처리완료: 738.bmp
# [519/4386] 처리완료: 4988.bmp
# [520/4386] 처리완료: 2254.bmp
# [521/4386] 처리완료: 2261.bmp
# [522/4386] 처리완료: 4286.bmp
# [523/4386] 처리완료: 1495.bmp
# [524/4386] 처리완료: 4464.bmp
# [525/4386] 처리완료: 814.bmp
# [526/4386] 처리완료: 480.bmp
# [527/4386] 처리완료: 1152.bmp
# [528/4386] 처리완료: 1765.bmp
# [529/4386] 처리완료: 1220.bmp
# [530/4386] 처리완료: 2336.bmp
# [531/4386] 처리완료: 1013.bmp
# [532/4386] 처리완료: 3976.bmp
# [533/4386] 처리완료: 4261.bmp
# [534/4386] 처리완료: 5041.bmp
# [535/4386] 처리완료: 1233.bmp
# [536/4386] 처리완료: 1450.bmp
# [537/4386] 처리완료: 2104.bmp
# [538/4386] 처리완료: 57.bmp
# [539/4386] 처리완료: 4692.bmp
# [540/4386] 처리완료: 222.bmp
# [541/4386] 처리완료: 4825.bmp
# [542/4386] 처리완료: 498.bmp
# [543/4386] 처리완료: 4009.bmp
# [544/4386] 처리완료: 789.bmp
# [545/4386] 처리완료: 4576.bmp
# [546/4386] 처리완료: 4698.bmp
# [547/4386] 처리완료: 624.bmp
# [548/4386] 처리완료: 4877.bmp
# [549/4386] 처리완료: 1060.bmp
# [550/4386] 처리완료: 1009.bmp
# [551/4386] 처리완료: 3928.bmp
# [552/4386] 처리완료: 3038.bmp
# [553/4386] 처리완료: 2773.bmp
# [554/4386] 처리완료: 2242.bmp
# [555/4386] 처리완료: 1669.bmp
# [556/4386] 처리완료: 3684.bmp
# [557/4386] 처리완료: 1236.bmp
# [558/4386] 처리완료: 3654.bmp
# [559/4386] 처리완료: 2446.bmp
# [560/4386] 처리완료: 4499.bmp
# [561/4386] 처리완료: 982.bmp
# [562/4386] 처리완료: 1710.bmp
# [563/4386] 처리완료: 2061.bmp
# [564/4386] 처리완료: 4082.bmp
# [565/4386] 처리완료: 4133.bmp
# [566/4386] 처리완료: 101.bmp
# [567/4386] 처리완료: 2423.bmp
# [568/4386] 처리완료: 3502.bmp
# [569/4386] 처리완료: 285.bmp
# [570/4386] 처리완료: 586.bmp
# [571/4386] 처리완료: 5078.bmp
# [572/4386] 처리완료: 650.bmp
# [573/4386] 처리완료: 3920.bmp
# [574/4386] 처리완료: 4646.bmp
# [575/4386] 처리완료: 2199.bmp
# [576/4386] 처리완료: 2106.bmp
# [577/4386] 처리완료: 837.bmp
# [578/4386] 처리완료: 385.bmp
# [579/4386] 처리완료: 1592.bmp
# [580/4386] 처리완료: 3087.bmp
# [581/4386] 처리완료: 4005.bmp
# [582/4386] 처리완료: 953.bmp
# [583/4386] 처리완료: 1413.bmp
# [584/4386] 처리완료: 719.bmp
# [585/4386] 처리완료: 1348.bmp
# [586/4386] 처리완료: 293.bmp
# [587/4386] 처리완료: 4620.bmp
# [588/4386] 처리완료: 726.bmp
# [589/4386] 처리완료: 14.bmp
# [590/4386] 처리완료: 4901.bmp
# [591/4386] 처리완료: 1392.bmp
# [592/4386] 처리완료: 3947.bmp
# [593/4386] 처리완료: 5000.bmp
# [594/4386] 처리완료: 4493.bmp
# [595/4386] 처리완료: 2714.bmp
# [596/4386] 처리완료: 3339.bmp
# [597/4386] 처리완료: 5092.bmp
# [598/4386] 처리완료: 2688.bmp
# [599/4386] 처리완료: 2945.bmp
# [600/4386] 처리완료: 2649.bmp
# [601/4386] 처리완료: 818.bmp
# [602/4386] 처리완료: 3902.bmp
# [603/4386] 처리완료: 525.bmp
# [604/4386] 처리완료: 4601.bmp
# [605/4386] 처리완료: 1305.bmp
# [606/4386] 처리완료: 1338.bmp
# [607/4386] 처리완료: 5007.bmp
# [608/4386] 처리완료: 2753.bmp
# [609/4386] 처리완료: 2831.bmp
# [610/4386] 처리완료: 2407.bmp
# [611/4386] 처리완료: 166.bmp
# [612/4386] 처리완료: 4324.bmp
# [613/4386] 처리완료: 3705.bmp
# [614/4386] 처리완료: 41.bmp
# [615/4386] 처리완료: 3114.bmp
# [616/4386] 처리완료: 1562.bmp
# [617/4386] 처리완료: 5018.bmp
# [618/4386] 처리완료: 5080.bmp
# [619/4386] 처리완료: 205.bmp
# [620/4386] 처리완료: 1239.bmp
# [621/4386] 처리완료: 4412.bmp
# [622/4386] 처리완료: 2784.bmp
# [623/4386] 처리완료: 4732.bmp
# [624/4386] 처리완료: 4561.bmp
# [625/4386] 처리완료: 408.bmp
# [626/4386] 처리완료: 3662.bmp
# [627/4386] 처리완료: 3605.bmp
# [628/4386] 처리완료: 365.bmp
# [629/4386] 처리완료: 4697.bmp
# [630/4386] 처리완료: 3991.bmp
# [631/4386] 처리완료: 2502.bmp
# [632/4386] 처리완료: 3423.bmp
# [633/4386] 처리완료: 1702.bmp
# [634/4386] 처리완료: 1785.bmp
# [635/4386] 처리완료: 2720.bmp
# [636/4386] 처리완료: 342.bmp
# [637/4386] 처리완료: 4187.bmp
# [638/4386] 처리완료: 2590.bmp
# [639/4386] 처리완료: 899.bmp
# [640/4386] 처리완료: 2474.bmp
# [641/4386] 처리완료: 873.bmp
# [642/4386] 처리완료: 831.bmp
# [643/4386] 처리완료: 3391.bmp
# [644/4386] 처리완료: 1673.bmp
# [645/4386] 처리완료: 3836.bmp
# [646/4386] 처리완료: 20.bmp
# [647/4386] 처리완료: 1654.bmp
# [648/4386] 처리완료: 1722.bmp
# [649/4386] 처리완료: 1456.bmp
# [650/4386] 처리완료: 5037.bmp
# [651/4386] 처리완료: 3881.bmp
# [652/4386] 처리완료: 2421.bmp
# [653/4386] 처리완료: 4487.bmp
# [654/4386] 처리완료: 1130.bmp
# [655/4386] 처리완료: 1231.bmp
# [656/4386] 처리완료: 4976.bmp
# [657/4386] 처리완료: 2744.bmp
# [658/4386] 처리완료: 3174.bmp
# [659/4386] 처리완료: 1574.bmp
# [660/4386] 처리완료: 1790.bmp
# [661/4386] 처리완료: 1974.bmp
# [662/4386] 처리완료: 2528.bmp
# [663/4386] 처리완료: 35.bmp
# [664/4386] 처리완료: 1351.bmp
# [665/4386] 처리완료: 3101.bmp
# [666/4386] 처리완료: 2006.bmp
# [667/4386] 처리완료: 3941.bmp
# [668/4386] 처리완료: 2730.bmp
# [669/4386] 처리완료: 3631.bmp
# [670/4386] 처리완료: 1764.bmp
# [671/4386] 처리완료: 2468.bmp
# [672/4386] 처리완료: 1193.bmp
# [673/4386] 처리완료: 2557.bmp
# [674/4386] 처리완료: 1746.bmp
# [675/4386] 처리완료: 1097.bmp
# [676/4386] 처리완료: 5065.bmp
# [677/4386] 처리완료: 3562.bmp
# [678/4386] 처리완료: 1630.bmp
# [679/4386] 처리완료: 1956.bmp
# [680/4386] 처리완료: 2404.bmp
# [681/4386] 처리완료: 2039.bmp
# [682/4386] 처리완료: 2099.bmp
# [683/4386] 처리완료: 1159.bmp
# [684/4386] 처리완료: 2506.bmp
# [685/4386] 처리완료: 4930.bmp
# [686/4386] 처리완료: 4485.bmp
# [687/4386] 처리완료: 309.bmp
# [688/4386] 처리완료: 4879.bmp
# [689/4386] 처리완료: 1910.bmp
# [690/4386] 처리완료: 4514.bmp
# [691/4386] 처리완료: 4958.bmp
# [692/4386] 처리완료: 3419.bmp
# [693/4386] 처리완료: 4772.bmp
# [694/4386] 처리완료: 3089.bmp
# [695/4386] 처리완료: 3912.bmp
# [696/4386] 처리완료: 1045.bmp
# [697/4386] 처리완료: 946.bmp
# [698/4386] 처리완료: 3237.bmp
# [699/4386] 처리완료: 355.bmp
# [700/4386] 처리완료: 1898.bmp
# [701/4386] 처리완료: 4512.bmp
# [702/4386] 처리완료: 3397.bmp
# [703/4386] 처리완료: 2526.bmp
# [704/4386] 처리완료: 2580.bmp
# [705/4386] 처리완료: 52.bmp
# [706/4386] 처리완료: 4781.bmp
# [707/4386] 처리완료: 4703.bmp
# [708/4386] 처리완료: 233.bmp
# [709/4386] 처리완료: 4587.bmp
# [710/4386] 처리완료: 4678.bmp
# [711/4386] 처리완료: 3066.bmp
# [712/4386] 처리완료: 206.bmp
# [713/4386] 처리완료: 2017.bmp
# [714/4386] 처리완료: 3329.bmp
# [715/4386] 처리완료: 4490.bmp
# [716/4386] 처리완료: 4534.bmp
# [717/4386] 처리완료: 2224.bmp
# [718/4386] 처리완료: 1170.bmp
# [719/4386] 처리완료: 3838.bmp
# [720/4386] 처리완료: 3652.bmp
# [721/4386] 처리완료: 3642.bmp
# [722/4386] 처리완료: 440.bmp
# [723/4386] 처리완료: 1604.bmp
# [724/4386] 처리완료: 3943.bmp
# [725/4386] 처리완료: 3731.bmp
# [726/4386] 처리완료: 2309.bmp
# [727/4386] 처리완료: 1767.bmp
# [728/4386] 처리완료: 4955.bmp
# [729/4386] 처리완료: 3422.bmp
# [730/4386] 처리완료: 1783.bmp
# [731/4386] 처리완료: 1116.bmp
# [732/4386] 처리완료: 4318.bmp
# [733/4386] 처리완료: 2759.bmp
# [734/4386] 처리완료: 400.bmp
# [735/4386] 처리완료: 2314.bmp
# [736/4386] 처리완료: 2582.bmp
# [737/4386] 처리완료: 2501.bmp
# [738/4386] 처리완료: 4739.bmp
# [739/4386] 처리완료: 4541.bmp
# [740/4386] 처리완료: 4451.bmp
# [741/4386] 처리완료: 768.bmp
# [742/4386] 처리완료: 1516.bmp
# [743/4386] 처리완료: 3270.bmp
# [744/4386] 처리완료: 2273.bmp
# [745/4386] 처리완료: 3519.bmp
# [746/4386] 처리완료: 810.bmp
# [747/4386] 처리완료: 3312.bmp
# [748/4386] 처리완료: 1189.bmp
# [749/4386] 처리완료: 3277.bmp
# [750/4386] 처리완료: 1274.bmp
# [751/4386] 처리완료: 3229.bmp
# [752/4386] 처리완료: 4049.bmp
# [753/4386] 처리완료: 4913.bmp
# [754/4386] 처리완료: 3718.bmp
# [755/4386] 처리완료: 1570.bmp
# [756/4386] 처리완료: 2337.bmp
# [757/4386] 처리완료: 4853.bmp
# [758/4386] 처리완료: 4488.bmp
# [759/4386] 처리완료: 1798.bmp
# [760/4386] 처리완료: 3018.bmp
# [761/4386] 처리완료: 3529.bmp
# [762/4386] 처리완료: 2030.bmp
# [763/4386] 처리완료: 2415.bmp
# [764/4386] 처리완료: 4222.bmp
# [765/4386] 처리완료: 2318.bmp
# [766/4386] 처리완료: 4114.bmp
# [767/4386] 처리완료: 4417.bmp
# [768/4386] 처리완료: 1015.bmp
# [769/4386] 처리완료: 1639.bmp
# [770/4386] 처리완료: 4179.bmp
# [771/4386] 처리완료: 1786.bmp
# [772/4386] 처리완료: 3632.bmp
# [773/4386] 처리완료: 4218.bmp
# [774/4386] 처리완료: 2910.bmp
# [775/4386] 처리완료: 2418.bmp
# [776/4386] 처리완료: 3932.bmp
# [777/4386] 처리완료: 3934.bmp
# [778/4386] 처리완료: 2631.bmp
# [779/4386] 처리완료: 989.bmp
# [780/4386] 처리완료: 1650.bmp
# [781/4386] 처리완료: 535.bmp
# [782/4386] 처리완료: 2889.bmp
# [783/4386] 처리완료: 3655.bmp
# [784/4386] 처리완료: 382.bmp
# [785/4386] 처리완료: 5074.bmp
# [786/4386] 처리완료: 4257.bmp
# [787/4386] 처리완료: 4207.bmp
# [788/4386] 처리완료: 5033.bmp
# [789/4386] 처리완료: 1471.bmp
# [790/4386] 처리완료: 4519.bmp
# [791/4386] 처리완료: 23.bmp
# [792/4386] 처리완료: 4070.bmp
# [793/4386] 처리완료: 258.bmp
# [794/4386] 처리완료: 4051.bmp
# [795/4386] 처리완료: 2429.bmp
# [796/4386] 처리완료: 3424.bmp
# [797/4386] 처리완료: 4388.bmp
# [798/4386] 처리완료: 3771.bmp
# [799/4386] 처리완료: 4521.bmp
# [800/4386] 처리완료: 2809.bmp
# [801/4386] 처리완료: 4029.bmp
# [802/4386] 처리완료: 2038.bmp
# [803/4386] 처리완료: 3504.bmp
# [804/4386] 처리완료: 2702.bmp
# [805/4386] 처리완료: 3752.bmp
# [806/4386] 처리완료: 4560.bmp
# [807/4386] 처리완료: 458.bmp
# [808/4386] 처리완료: 3104.bmp
# [809/4386] 처리완료: 1336.bmp
# [810/4386] 처리완료: 3408.bmp
# [811/4386] 처리완료: 1034.bmp
# [812/4386] 처리완료: 2998.bmp
# [813/4386] 처리완료: 58.bmp
# [814/4386] 처리완료: 1359.bmp
# [815/4386] 처리완료: 444.bmp
# [816/4386] 처리완료: 2592.bmp
# [817/4386] 처리완료: 3400.bmp
# [818/4386] 처리완료: 1448.bmp
# [819/4386] 처리완료: 367.bmp
# [820/4386] 처리완료: 2901.bmp
# [821/4386] 처리완료: 3573.bmp
# [822/4386] 처리완료: 4609.bmp
# [823/4386] 처리완료: 1278.bmp
# [824/4386] 처리완료: 3661.bmp
# [825/4386] 처리완료: 455.bmp
# [826/4386] 처리완료: 1662.bmp
# [827/4386] 처리완료: 3173.bmp
# [828/4386] 처리완료: 1527.bmp
# [829/4386] 처리완료: 3842.bmp
# [830/4386] 처리완료: 2454.bmp
# [831/4386] 처리완료: 191.bmp
# [832/4386] 처리완료: 383.bmp
# [833/4386] 처리완료: 2798.bmp
# [834/4386] 처리완료: 2934.bmp
# [835/4386] 처리완료: 3859.bmp
# [836/4386] 처리완료: 4295.bmp
# [837/4386] 처리완료: 445.bmp
# [838/4386] 처리완료: 2626.bmp
# [839/4386] 처리완료: 4516.bmp
# [840/4386] 처리완료: 2366.bmp
# [841/4386] 처리완료: 1704.bmp
# [842/4386] 처리완료: 73.bmp
# [843/4386] 처리완료: 1012.bmp
# [844/4386] 처리완료: 168.bmp
# [845/4386] 처리완료: 104.bmp
# [846/4386] 처리완료: 1151.bmp
# [847/4386] 처리완료: 503.bmp
# [848/4386] 처리완료: 3219.bmp
# [849/4386] 처리완료: 1916.bmp
# [850/4386] 처리완료: 2728.bmp
# [851/4386] 처리완료: 3656.bmp
# [852/4386] 처리완료: 4176.bmp
# [853/4386] 처리완료: 3669.bmp
# [854/4386] 처리완료: 185.bmp
# [855/4386] 처리완료: 3946.bmp
# [856/4386] 처리완료: 1588.bmp
# [857/4386] 처리완료: 2865.bmp
# [858/4386] 처리완료: 4844.bmp
# [859/4386] 처리완료: 4946.bmp
# [860/4386] 처리완료: 1270.bmp
# [861/4386] 처리완료: 2046.bmp
# [862/4386] 처리완료: 1569.bmp
# [863/4386] 처리완료: 3139.bmp
# [864/4386] 처리완료: 1022.bmp
# [865/4386] 처리완료: 4102.bmp
# [866/4386] 처리완료: 3565.bmp
# [867/4386] 처리완료: 3609.bmp
# [868/4386] 처리완료: 2572.bmp
# [869/4386] 처리완료: 2393.bmp
# [870/4386] 처리완료: 2519.bmp
# [871/4386] 처리완료: 620.bmp
# [872/4386] 처리완료: 237.bmp
# [873/4386] 처리완료: 3699.bmp
# [874/4386] 처리완료: 4017.bmp
# [875/4386] 처리완료: 5095.bmp
# [876/4386] 처리완료: 420.bmp
# [877/4386] 처리완료: 5024.bmp
# [878/4386] 처리완료: 3913.bmp
# [879/4386] 처리완료: 4924.bmp
# [880/4386] 처리완료: 2518.bmp
# [881/4386] 처리완료: 2923.bmp
# [882/4386] 처리완료: 4131.bmp
# [883/4386] 처리완료: 4761.bmp
# [884/4386] 처리완료: 2316.bmp
# [885/4386] 처리완료: 3854.bmp
# [886/4386] 처리완료: 4860.bmp
# [887/4386] 처리완료: 217.bmp
# [888/4386] 처리완료: 656.bmp
# [889/4386] 처리완료: 4118.bmp
# [890/4386] 처리완료: 410.bmp
# [891/4386] 처리완료: 109.bmp
# [892/4386] 처리완료: 694.bmp
# [893/4386] 처리완료: 2124.bmp
# [894/4386] 처리완료: 1837.bmp
# [895/4386] 처리완료: 288.bmp
# [896/4386] 처리완료: 2890.bmp
# [897/4386] 처리완료: 1138.bmp
# [898/4386] 처리완료: 4046.bmp
# [899/4386] 처리완료: 903.bmp
# [900/4386] 처리완료: 1205.bmp
# [901/4386] 처리완료: 3729.bmp
# [902/4386] 처리완료: 4404.bmp
# [903/4386] 처리완료: 301.bmp
# [904/4386] 처리완료: 2135.bmp
# [905/4386] 처리완료: 487.bmp
# [906/4386] 처리완료: 3477.bmp
# [907/4386] 처리완료: 162.bmp
# [908/4386] 처리완료: 3488.bmp
# [909/4386] 처리완료: 1535.bmp
# [910/4386] 처리완료: 2436.bmp
# [911/4386] 처리완료: 2172.bmp
# [912/4386] 처리완료: 2621.bmp
# [913/4386] 처리완료: 5005.bmp
# [914/4386] 처리완료: 1589.bmp
# [915/4386] 처리완료: 4081.bmp
# [916/4386] 처리완료: 4035.bmp
# [917/4386] 처리완료: 4192.bmp
# [918/4386] 처리완료: 2072.bmp
# [919/4386] 처리완료: 2069.bmp
# [920/4386] 처리완료: 2644.bmp
# [921/4386] 처리완료: 1183.bmp
# [922/4386] 처리완료: 1358.bmp
# [923/4386] 처리완료: 3911.bmp
# [924/4386] 처리완료: 3463.bmp
# [925/4386] 처리완료: 2918.bmp
# [926/4386] 처리완료: 1414.bmp
# [927/4386] 처리완료: 4832.bmp
# [928/4386] 처리완료: 450.bmp
# [929/4386] 처리완료: 2612.bmp
# [930/4386] 처리완료: 2959.bmp
# [931/4386] 처리완료: 5040.bmp
# [932/4386] 처리완료: 1242.bmp
# [933/4386] 처리완료: 3666.bmp
# [934/4386] 처리완료: 1426.bmp
# [935/4386] 처리완료: 2319.bmp
# [936/4386] 처리완료: 213.bmp
# [937/4386] 처리완료: 1096.bmp
# [938/4386] 처리완료: 1556.bmp
# [939/4386] 처리완료: 2193.bmp
# [940/4386] 처리완료: 1218.bmp
# [941/4386] 처리완료: 1146.bmp
# [942/4386] 처리완료: 2132.bmp
# [943/4386] 처리완료: 299.bmp
# [944/4386] 처리완료: 4628.bmp
# [945/4386] 처리완료: 194.bmp
# [946/4386] 처리완료: 3014.bmp
# [947/4386] 처리완료: 1103.bmp
# [948/4386] 처리완료: 3910.bmp
# [949/4386] 처리완료: 910.bmp
# [950/4386] 처리완료: 3179.bmp
# [951/4386] 처리완료: 192.bmp
# [952/4386] 처리완료: 3649.bmp
# [953/4386] 처리완료: 3327.bmp
# [954/4386] 처리완료: 4524.bmp
# [955/4386] 처리완료: 481.bmp
# [956/4386] 처리완료: 1033.bmp
# [957/4386] 처리완료: 5012.bmp
# [958/4386] 처리완료: 2756.bmp
# [959/4386] 처리완료: 2760.bmp
# [960/4386] 처리완료: 2089.bmp
# [961/4386] 처리완료: 2879.bmp
# [962/4386] 처리완료: 3993.bmp
# [963/4386] 처리완료: 1890.bmp
# [964/4386] 처리완료: 2166.bmp
# [965/4386] 처리완료: 3305.bmp
# [966/4386] 처리완료: 1853.bmp
# [967/4386] 처리완료: 4141.bmp
# [968/4386] 처리완료: 3744.bmp
# [969/4386] 처리완료: 4024.bmp
# [970/4386] 처리완료: 4910.bmp
# [971/4386] 처리완료: 1244.bmp
# [972/4386] 처리완료: 1567.bmp
# [973/4386] 처리완료: 2340.bmp
# [974/4386] 처리완료: 286.bmp
# [975/4386] 처리완료: 564.bmp
# [976/4386] 처리완료: 1092.bmp
# [977/4386] 처리완료: 2791.bmp
# [978/4386] 처리완료: 2258.bmp
# [979/4386] 처리완료: 2413.bmp
# [980/4386] 처리완료: 1924.bmp
# [981/4386] 처리완료: 1207.bmp
# [982/4386] 처리완료: 4644.bmp
# [983/4386] 처리완료: 3546.bmp
# [984/4386] 처리완료: 3658.bmp
# [985/4386] 처리완료: 1815.bmp
# [986/4386] 처리완료: 4152.bmp
# [987/4386] 처리완료: 5025.bmp
# [988/4386] 처리완료: 541.bmp
# [989/4386] 처리완료: 1292.bmp
# [990/4386] 처리완료: 434.bmp
# [991/4386] 처리완료: 4917.bmp
# [992/4386] 처리완료: 4857.bmp
# [993/4386] 처리완료: 693.bmp
# [994/4386] 처리완료: 4294.bmp
# [995/4386] 처리완료: 1906.bmp
# [996/4386] 처리완료: 369.bmp
# [997/4386] 처리완료: 3106.bmp
# [998/4386] 처리완료: 2511.bmp
# [999/4386] 처리완료: 2456.bmp
# [1000/4386] 처리완료: 2912.bmp
# [1001/4386] 처리완료: 3753.bmp
# [1002/4386] 처리완료: 3375.bmp
# [1003/4386] 처리완료: 5036.bmp
# [1004/4386] 처리완료: 3829.bmp
# [1005/4386] 처리완료: 2213.bmp
# [1006/4386] 처리완료: 1903.bmp
# [1007/4386] 처리완료: 40.bmp
# [1008/4386] 처리완료: 1734.bmp
# [1009/4386] 처리완료: 4836.bmp
# [1010/4386] 처리완료: 3033.bmp
# [1011/4386] 처리완료: 4663.bmp
# [1012/4386] 처리완료: 2127.bmp
# [1013/4386] 처리완료: 1498.bmp
# [1014/4386] 처리완료: 1269.bmp
# [1015/4386] 처리완료: 4196.bmp
# [1016/4386] 처리완료: 3970.bmp
# [1017/4386] 처리완료: 1860.bmp
# [1018/4386] 처리완료: 977.bmp
# [1019/4386] 처리완료: 4786.bmp
# [1020/4386] 처리완료: 3069.bmp
# [1021/4386] 처리완료: 2570.bmp
# [1022/4386] 처리완료: 2480.bmp
# [1023/4386] 처리완료: 2585.bmp
# [1024/4386] 처리완료: 2322.bmp
# [1025/4386] 처리완료: 3103.bmp
# [1026/4386] 처리완료: 3847.bmp
# [1027/4386] 처리완료: 1463.bmp
# [1028/4386] 처리완료: 4095.bmp
# [1029/4386] 처리완료: 358.bmp
# [1030/4386] 처리완료: 2693.bmp
# [1031/4386] 처리완료: 1222.bmp
# [1032/4386] 처리완료: 3156.bmp
# [1033/4386] 처리완료: 1838.bmp
# [1034/4386] 처리완료: 732.bmp
# [1035/4386] 처리완료: 3416.bmp
# [1036/4386] 처리완료: 4123.bmp
# [1037/4386] 처리완료: 1546.bmp
# [1038/4386] 처리완료: 3601.bmp
# [1039/4386] 처리완료: 526.bmp
# [1040/4386] 처리완료: 2397.bmp
# [1041/4386] 처리완료: 2183.bmp
# [1042/4386] 처리완료: 5087.bmp
# [1043/4386] 처리완료: 4201.bmp
# [1044/4386] 처리완료: 2201.bmp
# [1045/4386] 처리완료: 5001.bmp
# [1046/4386] 처리완료: 4395.bmp
# [1047/4386] 처리완료: 3530.bmp
# [1048/4386] 처리완료: 2878.bmp
# [1049/4386] 처리완료: 228.bmp
# [1050/4386] 처리완료: 117.bmp
# [1051/4386] 처리완료: 3672.bmp
# [1052/4386] 처리완료: 3217.bmp
# [1053/4386] 처리완료: 67.bmp
# [1054/4386] 처리완료: 3269.bmp
# [1055/4386] 처리완료: 2470.bmp
# [1056/4386] 처리완료: 1563.bmp
# [1057/4386] 처리완료: 816.bmp
# [1058/4386] 처리완료: 2634.bmp
# [1059/4386] 처리완료: 4400.bmp
# [1060/4386] 처리완료: 3944.bmp
# [1061/4386] 처리완료: 4745.bmp
# [1062/4386] 처리완료: 2282.bmp
# [1063/4386] 처리완료: 2372.bmp
# [1064/4386] 처리완료: 1849.bmp
# [1065/4386] 처리완료: 4407.bmp
# [1066/4386] 처리완료: 4508.bmp
# [1067/4386] 처리완료: 1364.bmp
# [1068/4386] 처리완료: 307.bmp
# [1069/4386] 처리완료: 2358.bmp
# [1070/4386] 처리완료: 1221.bmp
# [1071/4386] 처리완료: 1317.bmp
# [1072/4386] 처리완료: 4650.bmp
# [1073/4386] 처리완료: 4716.bmp
# [1074/4386] 처리완료: 3512.bmp
# [1075/4386] 처리완료: 1810.bmp
# [1076/4386] 처리완료: 1429.bmp
# [1077/4386] 처리완료: 4643.bmp
# [1078/4386] 처리완료: 2031.bmp
# [1079/4386] 처리완료: 3918.bmp
# [1080/4386] 처리완료: 521.bmp
# [1081/4386] 처리완료: 2118.bmp
# [1082/4386] 처리완료: 2207.bmp
# [1083/4386] 처리완료: 607.bmp
# [1084/4386] 처리완료: 3825.bmp
# [1085/4386] 처리완료: 1687.bmp
# [1086/4386] 처리완료: 3874.bmp
# [1087/4386] 처리완료: 2049.bmp
# [1088/4386] 처리완료: 2602.bmp
# [1089/4386] 처리완료: 3259.bmp
# [1090/4386] 처리완료: 1247.bmp
# [1091/4386] 처리완료: 4810.bmp
# [1092/4386] 처리완료: 2689.bmp
# [1093/4386] 처리완료: 4993.bmp
# [1094/4386] 처리완료: 4642.bmp
# [1095/4386] 처리완료: 3298.bmp
# [1096/4386] 처리완료: 625.bmp
# [1097/4386] 처리완료: 1418.bmp
# [1098/4386] 처리완료: 606.bmp
# [1099/4386] 처리완료: 4989.bmp
# [1100/4386] 처리완료: 5021.bmp
# [1101/4386] 처리완료: 2990.bmp
# [1102/4386] 처리완료: 4869.bmp
# [1103/4386] 처리완료: 2228.bmp
# [1104/4386] 처리완료: 1749.bmp
# [1105/4386] 처리완료: 5026.bmp
# [1106/4386] 처리완료: 860.bmp
# [1107/4386] 처리완료: 125.bmp
# [1108/4386] 처리완료: 2231.bmp
# [1109/4386] 처리완료: 1310.bmp
# [1110/4386] 처리완료: 421.bmp
# [1111/4386] 처리완료: 1087.bmp
# [1112/4386] 처리완료: 1510.bmp
# [1113/4386] 처리완료: 4833.bmp
# [1114/4386] 처리완료: 5094.bmp
# [1115/4386] 처리완료: 3441.bmp
# [1116/4386] 처리완료: 282.bmp
# [1117/4386] 처리완료: 3206.bmp
# [1118/4386] 처리완료: 3097.bmp
# [1119/4386] 처리완료: 825.bmp
# [1120/4386] 처리완료: 4937.bmp
# [1121/4386] 처리완료: 2424.bmp
# [1122/4386] 처리완료: 2257.bmp
# [1123/4386] 처리완료: 37.bmp
# [1124/4386] 처리완료: 4546.bmp
# [1125/4386] 처리완료: 878.bmp
# [1126/4386] 처리완료: 2252.bmp
# [1127/4386] 처리완료: 4289.bmp
# [1128/4386] 처리완료: 2150.bmp
# [1129/4386] 처리완료: 687.bmp
# [1130/4386] 처리완료: 2844.bmp
# [1131/4386] 처리완료: 2909.bmp
# [1132/4386] 처리완료: 3240.bmp
# [1133/4386] 처리완료: 3192.bmp
# [1134/4386] 처리완료: 1553.bmp
# [1135/4386] 처리완료: 2460.bmp
# [1136/4386] 처리완료: 1017.bmp
# [1137/4386] 처리완료: 2725.bmp
# [1138/4386] 처리완료: 4807.bmp
# [1139/4386] 처리완료: 4895.bmp
# [1140/4386] 처리완료: 4694.bmp
# [1141/4386] 처리완료: 3402.bmp
# [1142/4386] 처리완료: 3768.bmp
# [1143/4386] 처리완료: 3849.bmp
# [1144/4386] 처리완료: 2873.bmp
# [1145/4386] 처리완료: 757.bmp
# [1146/4386] 처리완료: 3068.bmp
# [1147/4386] 처리완료: 2108.bmp
# [1148/4386] 처리완료: 4251.bmp
# [1149/4386] 처리완료: 71.bmp
# [1150/4386] 처리완료: 1566.bmp
# [1151/4386] 처리완료: 3538.bmp
# [1152/4386] 처리완료: 1428.bmp
# [1153/4386] 처리완료: 250.bmp
# [1154/4386] 처리완료: 1469.bmp
# [1155/4386] 처리완료: 175.bmp
# [1156/4386] 처리완료: 3554.bmp
# [1157/4386] 처리완료: 1557.bmp
# [1158/4386] 처리완료: 1772.bmp
# [1159/4386] 처리완료: 1453.bmp
# [1160/4386] 처리완료: 1417.bmp
# [1161/4386] 처리완료: 4796.bmp
# [1162/4386] 처리완료: 3702.bmp
# [1163/4386] 처리완료: 2412.bmp
# [1164/4386] 처리완료: 1110.bmp
# [1165/4386] 처리완료: 3150.bmp
# [1166/4386] 처리완료: 2244.bmp
# [1167/4386] 처리완료: 3790.bmp
# [1168/4386] 처리완료: 1753.bmp
# [1169/4386] 처리완료: 2846.bmp
# [1170/4386] 처리완료: 4085.bmp
# [1171/4386] 처리완료: 1068.bmp
# [1172/4386] 처리완료: 2348.bmp
# [1173/4386] 처리완료: 2825.bmp
# [1174/4386] 처리완료: 4063.bmp
# [1175/4386] 처리완료: 4022.bmp
# [1176/4386] 처리완료: 111.bmp
# [1177/4386] 처리완료: 677.bmp
# [1178/4386] 처리완료: 3065.bmp
# [1179/4386] 처리완료: 3497.bmp
# [1180/4386] 처리완료: 1319.bmp
# [1181/4386] 처리완료: 1610.bmp
# [1182/4386] 처리완료: 784.bmp
# [1183/4386] 처리완료: 2481.bmp
# [1184/4386] 처리완료: 2678.bmp
# [1185/4386] 처리완료: 3213.bmp
# [1186/4386] 처리완료: 1581.bmp
# [1187/4386] 처리완료: 3674.bmp
# [1188/4386] 처리완료: 415.bmp
# [1189/4386] 처리완료: 3673.bmp
# [1190/4386] 처리완료: 2181.bmp
# [1191/4386] 처리완료: 4086.bmp
# [1192/4386] 처리완료: 4878.bmp
# [1193/4386] 처리완료: 2598.bmp
# [1194/4386] 처리완료: 268.bmp
# [1195/4386] 처리완료: 422.bmp
# [1196/4386] 처리완료: 1812.bmp
# [1197/4386] 처리완료: 887.bmp
# [1198/4386] 처리완료: 2100.bmp
# [1199/4386] 처리완료: 1532.bmp
# [1200/4386] 처리완료: 5090.bmp
# [1201/4386] 처리완료: 3585.bmp
# [1202/4386] 처리완료: 4513.bmp
# [1203/4386] 처리완료: 4279.bmp
# [1204/4386] 처리완료: 623.bmp
# [1205/4386] 처리완료: 4820.bmp
# [1206/4386] 처리완료: 2010.bmp
# [1207/4386] 처리완료: 572.bmp
# [1208/4386] 처리완료: 4216.bmp
# [1209/4386] 처리완료: 2950.bmp
# [1210/4386] 처리완료: 2245.bmp
# [1211/4386] 처리완료: 513.bmp
# [1212/4386] 처리완료: 1389.bmp
# [1213/4386] 처리완료: 1108.bmp
# [1214/4386] 처리완료: 4151.bmp
# [1215/4386] 처리완료: 4778.bmp
# [1216/4386] 처리완료: 4672.bmp
# [1217/4386] 처리완료: 1882.bmp
# [1218/4386] 처리완료: 2472.bmp
# [1219/4386] 처리완료: 3967.bmp
# [1220/4386] 처리완료: 1368.bmp
# [1221/4386] 처리완료: 725.bmp
# [1222/4386] 처리완료: 2614.bmp
# [1223/4386] 처리완료: 3491.bmp
# [1224/4386] 처리완료: 4276.bmp
# [1225/4386] 처리완료: 31.bmp
# [1226/4386] 처리완료: 1383.bmp
# [1227/4386] 처리완료: 2738.bmp
# [1228/4386] 처리완료: 2141.bmp
# [1229/4386] 처리완료: 4759.bmp
# [1230/4386] 처리완료: 803.bmp
# [1231/4386] 처리완료: 2633.bmp
# [1232/4386] 처리완료: 3387.bmp
# [1233/4386] 처리완료: 3906.bmp
# [1234/4386] 처리완료: 1400.bmp
# [1235/4386] 처리완료: 3737.bmp
# [1236/4386] 처리완료: 968.bmp
# [1237/4386] 처리완료: 1006.bmp
# [1238/4386] 처리완료: 902.bmp
# [1239/4386] 처리완료: 2292.bmp
# [1240/4386] 처리완료: 996.bmp
# [1241/4386] 처리완료: 4750.bmp
# [1242/4386] 처리완료: 778.bmp
# [1243/4386] 처리완료: 472.bmp
# [1244/4386] 처리완료: 3889.bmp
# [1245/4386] 처리완료: 3598.bmp
# [1246/4386] 처리완료: 4182.bmp
# [1247/4386] 처리완료: 2497.bmp
# [1248/4386] 처리완료: 26.bmp
# [1249/4386] 처리완료: 4577.bmp
# [1250/4386] 처리완료: 641.bmp
# [1251/4386] 처리완료: 69.bmp
# [1252/4386] 처리완료: 828.bmp
# [1253/4386] 처리완료: 5063.bmp
# [1254/4386] 처리완료: 2906.bmp
# [1255/4386] 처리완료: 1846.bmp
# [1256/4386] 처리완료: 3541.bmp
# [1257/4386] 처리완료: 1082.bmp
# [1258/4386] 처리완료: 3073.bmp
# [1259/4386] 처리완료: 1506.bmp
# [1260/4386] 처리완료: 711.bmp
# [1261/4386] 처리완료: 2439.bmp
# [1262/4386] 처리완료: 1877.bmp
# [1263/4386] 처리완료: 3399.bmp
# [1264/4386] 처리완료: 1953.bmp
# [1265/4386] 처리완료: 3370.bmp
# [1266/4386] 처리완료: 1966.bmp
# [1267/4386] 처리완료: 4925.bmp
# [1268/4386] 처리완료: 1136.bmp
# [1269/4386] 처리완료: 2334.bmp
# [1270/4386] 처리완료: 800.bmp
# [1271/4386] 처리완료: 3777.bmp
# [1272/4386] 처리완료: 2680.bmp
# [1273/4386] 처리완료: 4274.bmp
# [1274/4386] 처리완료: 4107.bmp
# [1275/4386] 처리완료: 4510.bmp
# [1276/4386] 처리완료: 370.bmp
# [1277/4386] 처리완료: 1216.bmp
# [1278/4386] 처리완료: 1004.bmp
# [1279/4386] 처리완료: 1548.bmp
# [1280/4386] 처리완료: 950.bmp
# [1281/4386] 처리완료: 4935.bmp
# [1282/4386] 처리완료: 3123.bmp
# [1283/4386] 처리완료: 2453.bmp
# [1284/4386] 처리완료: 4212.bmp
# [1285/4386] 처리완료: 438.bmp
# [1286/4386] 처리완료: 4723.bmp
# [1287/4386] 처리완료: 3534.bmp
# [1288/4386] 처리완료: 858.bmp
# [1289/4386] 처리완료: 2986.bmp
# [1290/4386] 처리완료: 3540.bmp
# [1291/4386] 처리완료: 882.bmp
# [1292/4386] 처리완료: 2968.bmp
# [1293/4386] 처리완료: 940.bmp
# [1294/4386] 처리완료: 847.bmp
# [1295/4386] 처리완료: 2540.bmp
# [1296/4386] 처리완료: 4410.bmp
# [1297/4386] 처리완료: 5022.bmp
# [1298/4386] 처리완료: 2285.bmp
# [1299/4386] 처리완료: 3427.bmp
# [1300/4386] 처리완료: 384.bmp
# [1301/4386] 처리완료: 4076.bmp
# [1302/4386] 처리완료: 1070.bmp
# [1303/4386] 처리완료: 2573.bmp
# [1304/4386] 처리완료: 1410.bmp
# [1305/4386] 처리완료: 4972.bmp
# [1306/4386] 처리완료: 2819.bmp
# [1307/4386] 처리완료: 4072.bmp
# [1308/4386] 처리완료: 896.bmp
# [1309/4386] 처리완료: 1069.bmp
# [1310/4386] 처리완료: 3800.bmp
# [1311/4386] 처리완료: 1896.bmp
# [1312/4386] 처리완료: 3053.bmp
# [1313/4386] 처리완료: 2062.bmp
# [1314/4386] 처리완료: 1634.bmp
# [1315/4386] 처리완료: 3953.bmp
# [1316/4386] 처리완료: 116.bmp
# [1317/4386] 처리완료: 1385.bmp
# [1318/4386] 처리완료: 3494.bmp
# [1319/4386] 처리완료: 4427.bmp
# [1320/4386] 처리완료: 1164.bmp
# [1321/4386] 처리완료: 1470.bmp
# [1322/4386] 처리완료: 626.bmp
# [1323/4386] 처리완료: 3956.bmp
# [1324/4386] 처리완료: 1201.bmp
# [1325/4386] 처리완료: 4305.bmp
# [1326/4386] 처리완료: 3614.bmp
# [1327/4386] 처리완료: 4242.bmp
# [1328/4386] 처리완료: 429.bmp
# [1329/4386] 처리완료: 1472.bmp
# [1330/4386] 처리완료: 3313.bmp
# [1331/4386] 처리완료: 925.bmp
# [1332/4386] 처리완료: 461.bmp
# [1333/4386] 처리완료: 3770.bmp
# [1334/4386] 처리완료: 2146.bmp
# [1335/4386] 처리완료: 1054.bmp
# [1336/4386] 처리완료: 4585.bmp
# [1337/4386] 처리완료: 4506.bmp
# [1338/4386] 처리완료: 3754.bmp
# [1339/4386] 처리완료: 3020.bmp
# [1340/4386] 처리완료: 1160.bmp
# [1341/4386] 처리완료: 2156.bmp
# [1342/4386] 처리완료: 776.bmp
# [1343/4386] 처리완료: 2353.bmp
# [1344/4386] 처리완료: 464.bmp
# [1345/4386] 처리완료: 2872.bmp
# [1346/4386] 처리완료: 157.bmp
# [1347/4386] 처리완료: 898.bmp
# [1348/4386] 처리완료: 1564.bmp
# [1349/4386] 처리완료: 1845.bmp
# [1350/4386] 처리완료: 3811.bmp
# [1351/4386] 처리완료: 4967.bmp
# [1352/4386] 처리완료: 3479.bmp
# [1353/4386] 처리완료: 3256.bmp
# [1354/4386] 처리완료: 2175.bmp
# [1355/4386] 처리완료: 357.bmp
# [1356/4386] 처리완료: 226.bmp
# [1357/4386] 처리완료: 436.bmp
# [1358/4386] 처리완료: 1628.bmp
# [1359/4386] 처리완료: 4496.bmp
# [1360/4386] 처리완료: 3767.bmp
# [1361/4386] 처리완료: 4724.bmp
# [1362/4386] 처리완료: 4112.bmp
# [1363/4386] 처리완료: 280.bmp
# [1364/4386] 처리완료: 1904.bmp
# [1365/4386] 처리완료: 5039.bmp
# [1366/4386] 처리완료: 1645.bmp
# [1367/4386] 처리완료: 3915.bmp
# [1368/4386] 처리완료: 3478.bmp
# [1369/4386] 처리완료: 2854.bmp
# [1370/4386] 처리완료: 2941.bmp
# [1371/4386] 처리완료: 1692.bmp
# [1372/4386] 처리완료: 2623.bmp
# [1373/4386] 처리완료: 765.bmp
# [1374/4386] 처리완료: 4194.bmp
# [1375/4386] 처리완료: 4676.bmp
# [1376/4386] 처리완료: 4802.bmp
# [1377/4386] 처리완료: 1332.bmp
# [1378/4386] 처리완료: 4310.bmp
# [1379/4386] 처리완료: 1053.bmp
# [1380/4386] 처리완료: 919.bmp
# [1381/4386] 처리완료: 2280.bmp
# [1382/4386] 처리완료: 2303.bmp
# [1383/4386] 처리완료: 2574.bmp
# [1384/4386] 처리완료: 68.bmp
# [1385/4386] 처리완료: 1093.bmp
# [1386/4386] 처리완료: 407.bmp
# [1387/4386] 처리완료: 2232.bmp
# [1388/4386] 처리완료: 3355.bmp
# [1389/4386] 처리완료: 4119.bmp
# [1390/4386] 처리완료: 2505.bmp
# [1391/4386] 처리완료: 82.bmp
# [1392/4386] 처리완료: 2073.bmp
# [1393/4386] 처리완료: 704.bmp
# [1394/4386] 처리완료: 842.bmp
# [1395/4386] 처리완료: 1526.bmp
# [1396/4386] 처리완료: 344.bmp
# [1397/4386] 처리완료: 4272.bmp
# [1398/4386] 처리완료: 160.bmp
# [1399/4386] 처리완료: 1598.bmp
# [1400/4386] 처리완료: 4649.bmp
# [1401/4386] 처리완료: 2884.bmp
# [1402/4386] 처리완료: 2513.bmp
# [1403/4386] 처리완료: 2992.bmp
# [1404/4386] 처리완료: 428.bmp
# [1405/4386] 처리완료: 3891.bmp
# [1406/4386] 처리완료: 4470.bmp
# [1407/4386] 처리완료: 3578.bmp
# [1408/4386] 처리완료: 1408.bmp
# [1409/4386] 처리완료: 4994.bmp
# [1410/4386] 처리완료: 3734.bmp
# [1411/4386] 처리완료: 4298.bmp
# [1412/4386] 처리완료: 3968.bmp
# [1413/4386] 처리완료: 2408.bmp
# [1414/4386] 처리완료: 3328.bmp
# [1415/4386] 처리완료: 3627.bmp
# [1416/4386] 처리완료: 974.bmp
# [1417/4386] 처리완료: 2033.bmp
# [1418/4386] 처리완료: 2249.bmp
# [1419/4386] 처리완료: 797.bmp
# [1420/4386] 처리완료: 3762.bmp
# [1421/4386] 처리완료: 3517.bmp
# [1422/4386] 처리완료: 5086.bmp
# [1423/4386] 처리완료: 3262.bmp
# [1424/4386] 처리완료: 1140.bmp
# [1425/4386] 처리완료: 126.bmp
# [1426/4386] 처리완료: 3550.bmp
# [1427/4386] 처리완료: 49.bmp
# [1428/4386] 처리완료: 1686.bmp
# [1429/4386] 처리완료: 4253.bmp
# [1430/4386] 처리완료: 129.bmp
# [1431/4386] 처리완료: 1508.bmp
# [1432/4386] 처리완료: 1612.bmp
# [1433/4386] 처리완료: 4228.bmp
# [1434/4386] 처리완료: 4293.bmp
# [1435/4386] 처리완료: 4533.bmp
# [1436/4386] 처리완료: 3460.bmp
# [1437/4386] 처리완료: 4462.bmp
# [1438/4386] 처리완료: 845.bmp
# [1439/4386] 처리완료: 2881.bmp
# [1440/4386] 처리완료: 2441.bmp
# [1441/4386] 처리완료: 935.bmp
# [1442/4386] 처리완료: 4171.bmp
# [1443/4386] 처리완료: 2897.bmp
# [1444/4386] 처리완료: 4754.bmp
# [1445/4386] 처리완료: 460.bmp
# [1446/4386] 처리완료: 3594.bmp
# [1447/4386] 처리완료: 702.bmp
# [1448/4386] 처리완료: 475.bmp
# [1449/4386] 처리완료: 876.bmp
# [1450/4386] 처리완료: 654.bmp
# [1451/4386] 처리완료: 3045.bmp
# [1452/4386] 처리완료: 4501.bmp
# [1453/4386] 처리완료: 855.bmp
# [1454/4386] 처리완료: 2709.bmp
# [1455/4386] 처리완료: 327.bmp
# [1456/4386] 처리완료: 3016.bmp
# [1457/4386] 처리완료: 272.bmp
# [1458/4386] 처리완료: 2138.bmp
# [1459/4386] 처리완료: 4419.bmp
# [1460/4386] 처리완료: 4831.bmp
# [1461/4386] 처리완료: 1773.bmp
# [1462/4386] 처리완료: 1806.bmp
# [1463/4386] 처리완료: 1056.bmp
# [1464/4386] 처리완료: 486.bmp
# [1465/4386] 처리완료: 4733.bmp
# [1466/4386] 처리완료: 1864.bmp
# [1467/4386] 처리완료: 1621.bmp
# [1468/4386] 처리완료: 3475.bmp
# [1469/4386] 처리완료: 100.bmp
# [1470/4386] 처리완료: 2140.bmp
# [1471/4386] 처리완료: 4154.bmp
# [1472/4386] 처리완료: 203.bmp
# [1473/4386] 처리완료: 3965.bmp
# [1474/4386] 처리완료: 2656.bmp
# [1475/4386] 처리완료: 482.bmp
# [1476/4386] 처리완료: 1175.bmp
# [1477/4386] 처리완료: 1452.bmp
# [1478/4386] 처리완료: 1608.bmp
# [1479/4386] 처리완료: 3410.bmp
# [1480/4386] 처리완료: 3281.bmp
# [1481/4386] 처리완료: 4527.bmp
# [1482/4386] 처리완료: 4535.bmp
# [1483/4386] 처리완료: 4855.bmp
# [1484/4386] 처리완료: 1777.bmp
# [1485/4386] 처리완료: 156.bmp
# [1486/4386] 처리완료: 1264.bmp
# [1487/4386] 처리완료: 3742.bmp
# [1488/4386] 처리완료: 2321.bmp
# [1489/4386] 처리완료: 189.bmp
# [1490/4386] 처리완료: 2078.bmp
# [1491/4386] 처리완료: 1076.bmp
# [1492/4386] 처리완료: 2718.bmp
# [1493/4386] 처리완료: 2541.bmp
# [1494/4386] 처리완료: 2938.bmp
# [1495/4386] 처리완료: 3155.bmp
# [1496/4386] 처리완료: 1001.bmp
# [1497/4386] 처리완료: 2977.bmp
# [1498/4386] 처리완료: 3544.bmp
# [1499/4386] 처리완료: 304.bmp
# [1500/4386] 처리완료: 4625.bmp
# [1501/4386] 처리완료: 148.bmp
# [1502/4386] 처리완료: 1735.bmp
# [1503/4386] 처리완료: 1121.bmp
# [1504/4386] 처리완료: 1671.bmp
# [1505/4386] 처리완료: 1194.bmp
# [1506/4386] 처리완료: 1980.bmp
# [1507/4386] 처리완료: 2776.bmp
# [1508/4386] 처리완료: 2849.bmp
# [1509/4386] 처리완료: 1992.bmp
# [1510/4386] 처리완료: 4896.bmp
# [1511/4386] 처리완료: 4142.bmp
# [1512/4386] 처리완료: 2416.bmp
# [1513/4386] 처리완료: 1353.bmp
# [1514/4386] 처리완료: 2020.bmp
# [1515/4386] 처리완료: 3826.bmp
# [1516/4386] 처리완료: 3561.bmp
# [1517/4386] 처리완료: 2684.bmp
# [1518/4386] 처리완료: 3154.bmp
# [1519/4386] 처리완료: 2326.bmp
# [1520/4386] 처리완료: 1217.bmp
# [1521/4386] 처리완료: 2544.bmp
# [1522/4386] 처리완료: 1048.bmp
# [1523/4386] 처리완료: 1367.bmp
# [1524/4386] 처리완료: 98.bmp
# [1525/4386] 처리완료: 2409.bmp
# [1526/4386] 처리완료: 696.bmp
# [1527/4386] 처리완료: 3482.bmp
# [1528/4386] 처리완료: 3558.bmp
# [1529/4386] 처리완료: 2533.bmp
# [1530/4386] 처리완료: 63.bmp
# [1531/4386] 처리완료: 3230.bmp
# [1532/4386] 처리완료: 3817.bmp
# [1533/4386] 처리완료: 2853.bmp
# [1534/4386] 처리완료: 2142.bmp
# [1535/4386] 처리완료: 169.bmp
# [1536/4386] 처리완료: 2398.bmp
# [1537/4386] 처리완료: 1215.bmp
# [1538/4386] 처리완료: 2364.bmp
# [1539/4386] 처리완료: 2392.bmp
# [1540/4386] 처리완료: 3872.bmp
# [1541/4386] 처리완료: 2115.bmp
# [1542/4386] 처리완료: 4453.bmp
# [1543/4386] 처리완료: 4461.bmp
# [1544/4386] 처리완료: 1134.bmp
# [1545/4386] 처리완료: 3615.bmp
# [1546/4386] 처리완료: 4045.bmp
# [1547/4386] 처리완료: 799.bmp
# [1548/4386] 처리완료: 4710.bmp
# [1549/4386] 처리완료: 983.bmp
# [1550/4386] 처리완료: 1942.bmp
# [1551/4386] 처리완료: 4193.bmp
# [1552/4386] 처리완료: 4241.bmp
# [1553/4386] 처리완료: 959.bmp
# [1554/4386] 처리완료: 4688.bmp
# [1555/4386] 처리완료: 775.bmp
# [1556/4386] 처리완료: 1149.bmp
# [1557/4386] 처리완료: 1301.bmp
# [1558/4386] 처리완료: 570.bmp
# [1559/4386] 처리완료: 3314.bmp
# [1560/4386] 처리완료: 805.bmp
# [1561/4386] 처리완료: 1957.bmp
# [1562/4386] 처리완료: 774.bmp
# [1563/4386] 처리완료: 553.bmp
# [1564/4386] 처리완료: 2449.bmp
# [1565/4386] 처리완료: 4016.bmp
# [1566/4386] 처리완료: 4478.bmp
# [1567/4386] 처리완료: 2133.bmp
# [1568/4386] 처리완료: 4838.bmp
# [1569/4386] 처리완료: 1399.bmp
# [1570/4386] 처리완료: 3757.bmp
# [1571/4386] 처리완료: 1868.bmp
# [1572/4386] 처리완료: 339.bmp
# [1573/4386] 처리완료: 3781.bmp
# [1574/4386] 처리완료: 2362.bmp
# [1575/4386] 처리완료: 928.bmp
# [1576/4386] 처리완료: 1391.bmp
# [1577/4386] 처리완료: 3896.bmp
# [1578/4386] 처리완료: 303.bmp
# [1579/4386] 처리완료: 3776.bmp
# [1580/4386] 처리완료: 1881.bmp
# [1581/4386] 처리완료: 3521.bmp
# [1582/4386] 처리완료: 1168.bmp
# [1583/4386] 처리완료: 1936.bmp
# [1584/4386] 처리완료: 4777.bmp
# [1585/4386] 처리완료: 3722.bmp
# [1586/4386] 처리완료: 3922.bmp
# [1587/4386] 처리완료: 2296.bmp
# [1588/4386] 처리완료: 1486.bmp
# [1589/4386] 처리완료: 2344.bmp
# [1590/4386] 처리완료: 2813.bmp
# [1591/4386] 처리완료: 36.bmp
# [1592/4386] 처리완료: 1248.bmp
# [1593/4386] 처리완료: 4481.bmp
# [1594/4386] 처리완료: 1855.bmp
# [1595/4386] 처리완료: 1125.bmp
# [1596/4386] 처리완료: 3648.bmp
# [1597/4386] 처리완료: 2997.bmp
# [1598/4386] 처리완료: 4416.bmp
# [1599/4386] 처리완료: 1952.bmp
# [1600/4386] 처리완료: 5048.bmp
# [1601/4386] 처리완료: 1008.bmp
# [1602/4386] 처리완료: 600.bmp
# [1603/4386] 처리완료: 2374.bmp
# [1604/4386] 처리완료: 2781.bmp
# [1605/4386] 처리완료: 1965.bmp
# [1606/4386] 처리완료: 2071.bmp
# [1607/4386] 처리완료: 311.bmp
# [1608/4386] 처리완료: 2522.bmp
# [1609/4386] 처리완료: 1300.bmp
# [1610/4386] 처리완료: 1970.bmp
# [1611/4386] 처리완료: 2304.bmp
# [1612/4386] 처리완료: 3195.bmp
# [1613/4386] 처리완료: 912.bmp
# [1614/4386] 처리완료: 559.bmp
# [1615/4386] 처리완료: 3282.bmp
# [1616/4386] 처리완료: 2757.bmp
# [1617/4386] 처리완료: 2004.bmp
# [1618/4386] 처리완료: 2478.bmp
# [1619/4386] 처리완료: 2450.bmp
# [1620/4386] 처리완료: 3385.bmp
# [1621/4386] 처리완료: 1007.bmp
# [1622/4386] 처리완료: 4431.bmp
# [1623/4386] 처리완료: 4740.bmp
# [1624/4386] 처리완료: 642.bmp
# [1625/4386] 처리완료: 3759.bmp
# [1626/4386] 처리완료: 2434.bmp
# [1627/4386] 처리완료: 4570.bmp
# [1628/4386] 처리완료: 1461.bmp
# [1629/4386] 처리완료: 2077.bmp
# [1630/4386] 처리완료: 0.bmp
# [1631/4386] 처리완료: 706.bmp
# [1632/4386] 처리완료: 786.bmp
# [1633/4386] 처리완료: 1388.bmp
# [1634/4386] 처리완료: 1416.bmp
# [1635/4386] 처리완료: 1455.bmp
# [1636/4386] 처리완료: 2059.bmp
# [1637/4386] 처리완료: 4840.bmp
# [1638/4386] 처리완료: 1986.bmp
# [1639/4386] 처리완료: 3176.bmp
# [1640/4386] 처리완료: 86.bmp
# [1641/4386] 처리완료: 3813.bmp
# [1642/4386] 처리완료: 2769.bmp
# [1643/4386] 처리완료: 2662.bmp
# [1644/4386] 처리완료: 2112.bmp
# [1645/4386] 처리완료: 146.bmp
# [1646/4386] 처리완료: 1322.bmp
# [1647/4386] 처리완료: 416.bmp
# [1648/4386] 처리완료: 4902.bmp
# [1649/4386] 처리완료: 4775.bmp
# [1650/4386] 처리완료: 888.bmp
# [1651/4386] 처리완료: 1695.bmp
# [1652/4386] 처리완료: 2290.bmp
# [1653/4386] 처리완료: 4021.bmp
# [1654/4386] 처리완료: 576.bmp
# [1655/4386] 처리완료: 2495.bmp
# [1656/4386] 처리완료: 2724.bmp
# [1657/4386] 처리완료: 4682.bmp
# [1658/4386] 처리완료: 4767.bmp
# [1659/4386] 처리완료: 2750.bmp
# [1660/4386] 처리완료: 2894.bmp
# [1661/4386] 처리완료: 2383.bmp
# [1662/4386] 처리완료: 2219.bmp
# [1663/4386] 처리완료: 196.bmp
# [1664/4386] 처리완료: 1696.bmp
# [1665/4386] 처리완료: 4978.bmp
# [1666/4386] 처리완료: 1078.bmp
# [1667/4386] 처리완료: 2658.bmp
# [1668/4386] 처리완료: 4536.bmp
# [1669/4386] 처리완료: 2003.bmp
# [1670/4386] 처리완료: 1929.bmp
# [1671/4386] 처리완료: 1074.bmp
# [1672/4386] 처리완료: 1994.bmp
# [1673/4386] 처리완료: 2076.bmp
# [1674/4386] 처리완료: 5054.bmp
# [1675/4386] 처리완료: 689.bmp
# [1676/4386] 처리완료: 783.bmp
# [1677/4386] 처리완료: 4003.bmp
# [1678/4386] 처리완료: 4529.bmp
# [1679/4386] 처리완료: 5052.bmp
# [1680/4386] 처리완료: 3586.bmp
# [1681/4386] 처리완료: 4997.bmp
# [1682/4386] 처리완료: 637.bmp
# [1683/4386] 처리완료: 1613.bmp
# [1684/4386] 처리완료: 306.bmp
# [1685/4386] 처리완료: 3415.bmp
# [1686/4386] 처리완료: 4234.bmp
# [1687/4386] 처리완료: 2898.bmp
# [1688/4386] 처리완료: 3975.bmp
# [1689/4386] 처리완료: 1741.bmp
# [1690/4386] 처리완료: 397.bmp
# [1691/4386] 처리완료: 337.bmp
# [1692/4386] 처리완료: 300.bmp
# [1693/4386] 처리완료: 4127.bmp
# [1694/4386] 처리완료: 5058.bmp
# [1695/4386] 처리완료: 4932.bmp
# [1696/4386] 처리완료: 3167.bmp
# [1697/4386] 처리완료: 2042.bmp
# [1698/4386] 처리완료: 1684.bmp
# [1699/4386] 처리완료: 2703.bmp
# [1700/4386] 처리완료: 5055.bmp
# [1701/4386] 처리완료: 4982.bmp
# [1702/4386] 처리완료: 3291.bmp
# [1703/4386] 처리완료: 3057.bmp
# [1704/4386] 처리완료: 973.bmp
# [1705/4386] 처리완료: 1118.bmp
# [1706/4386] 처리완료: 3360.bmp
# [1707/4386] 처리완료: 4326.bmp
# [1708/4386] 처리완료: 3864.bmp
# [1709/4386] 처리완료: 4749.bmp
# [1710/4386] 처리완료: 1176.bmp
# [1711/4386] 처리완료: 3958.bmp
# [1712/4386] 처리완료: 4384.bmp
# [1713/4386] 처리완료: 2632.bmp
# [1714/4386] 처리완료: 4822.bmp
# [1715/4386] 처리완료: 2259.bmp
# [1716/4386] 처리완료: 3031.bmp
# [1717/4386] 처리완료: 2443.bmp
# [1718/4386] 처리완료: 346.bmp
# [1719/4386] 처리완료: 479.bmp
# [1720/4386] 처리완료: 3004.bmp
# [1721/4386] 처리완료: 735.bmp
# [1722/4386] 처리완료: 1384.bmp
# [1723/4386] 처리완료: 3095.bmp
# [1724/4386] 처리완료: 4677.bmp
# [1725/4386] 처리완료: 172.bmp
# [1726/4386] 처리완료: 1762.bmp
# [1727/4386] 처리완료: 2029.bmp
# [1728/4386] 처리완료: 2880.bmp
# [1729/4386] 처리완료: 2190.bmp
# [1730/4386] 처리완료: 2205.bmp
# [1731/4386] 처리완료: 3205.bmp
# [1732/4386] 처리완료: 3559.bmp
# [1733/4386] 처리완료: 2035.bmp
# [1734/4386] 처리완료: 917.bmp
# [1735/4386] 처리완료: 3185.bmp
# [1736/4386] 처리완료: 2272.bmp
# [1737/4386] 처리완료: 2722.bmp
# [1738/4386] 처리완료: 3701.bmp
# [1739/4386] 처리완료: 4282.bmp
# [1740/4386] 처리완료: 4239.bmp
# [1741/4386] 처리완료: 5073.bmp
# [1742/4386] 처리완료: 2351.bmp
# [1743/4386] 처리완료: 4641.bmp
# [1744/4386] 처리완료: 201.bmp
# [1745/4386] 처리완료: 441.bmp
# [1746/4386] 처리완료: 448.bmp
# [1747/4386] 처리완료: 3368.bmp
# [1748/4386] 처리완료: 2174.bmp
# [1749/4386] 처리완료: 546.bmp
# [1750/4386] 처리완료: 3980.bmp
# [1751/4386] 처리완료: 1380.bmp
# [1752/4386] 처리완료: 3961.bmp
# [1753/4386] 처리완료: 3357.bmp
# [1754/4386] 처리완료: 4268.bmp
# [1755/4386] 처리완료: 1340.bmp
# [1756/4386] 처리완료: 682.bmp
# [1757/4386] 처리완료: 733.bmp
# [1758/4386] 처리완료: 2466.bmp
# [1759/4386] 처리완료: 238.bmp
# [1760/4386] 처리완료: 608.bmp
# [1761/4386] 처리완료: 3098.bmp
# [1762/4386] 처리완료: 2829.bmp
# [1763/4386] 처리완료: 4812.bmp
# [1764/4386] 처리완료: 1276.bmp
# [1765/4386] 처리완료: 1879.bmp
# [1766/4386] 처리완료: 3429.bmp
# [1767/4386] 처리완료: 647.bmp
# [1768/4386] 처리완료: 1295.bmp
# [1769/4386] 처리완료: 225.bmp
# [1770/4386] 처리완료: 5004.bmp
# [1771/4386] 처리완료: 218.bmp
# [1772/4386] 처리완료: 3238.bmp
# [1773/4386] 처리완료: 366.bmp
# [1774/4386] 처리완료: 3201.bmp
# [1775/4386] 처리완료: 3244.bmp
# [1776/4386] 처리완료: 84.bmp
# [1777/4386] 처리완료: 2317.bmp
# [1778/4386] 처리완료: 688.bmp
# [1779/4386] 처리완료: 368.bmp
# [1780/4386] 처리완료: 3905.bmp
# [1781/4386] 처리완료: 3472.bmp
# [1782/4386] 처리완료: 857.bmp
# [1783/4386] 처리완료: 745.bmp
# [1784/4386] 처리완료: 3457.bmp
# [1785/4386] 처리완료: 3280.bmp
# [1786/4386] 처리완료: 2740.bmp
# [1787/4386] 처리완료: 798.bmp
# [1788/4386] 처리완료: 4850.bmp
# [1789/4386] 처리완료: 4929.bmp
# [1790/4386] 처리완료: 2090.bmp
# [1791/4386] 처리완료: 4250.bmp
# [1792/4386] 처리완료: 3161.bmp
# [1793/4386] 처리완료: 4782.bmp
# [1794/4386] 처리완료: 621.bmp
# [1795/4386] 처리완료: 437.bmp
# [1796/4386] 처리완료: 2904.bmp
# [1797/4386] 처리완료: 3785.bmp
# [1798/4386] 처리완료: 2981.bmp
# [1799/4386] 처리완료: 1156.bmp
# [1800/4386] 처리완료: 3866.bmp
# [1801/4386] 처리완료: 2530.bmp
# [1802/4386] 처리완료: 2047.bmp
# [1803/4386] 처리완료: 3344.bmp
# [1804/4386] 처리완료: 2403.bmp
# [1805/4386] 처리완료: 4861.bmp
# [1806/4386] 처리완료: 4175.bmp
# [1807/4386] 처리완료: 4054.bmp
# [1808/4386] 처리완료: 2609.bmp
# [1809/4386] 처리완료: 4454.bmp
# [1810/4386] 처리완료: 4309.bmp
# [1811/4386] 처리완료: 4770.bmp
# [1812/4386] 처리완료: 3403.bmp
# [1813/4386] 처리완료: 4610.bmp
# [1814/4386] 처리완료: 4445.bmp
# [1815/4386] 처리완료: 2975.bmp
# [1816/4386] 처리완료: 4043.bmp
# [1817/4386] 처리완료: 1350.bmp
# [1818/4386] 처리완료: 3211.bmp
# [1819/4386] 처리완료: 4128.bmp
# [1820/4386] 처리완료: 1670.bmp
# [1821/4386] 처리완료: 2113.bmp
# [1822/4386] 처리완료: 3189.bmp
# [1823/4386] 처리완료: 2508.bmp
# [1824/4386] 처리완료: 2313.bmp
# [1825/4386] 처리완료: 2087.bmp
# [1826/4386] 처리완료: 2333.bmp
# [1827/4386] 처리완료: 4741.bmp
# [1828/4386] 처리완료: 4945.bmp
# [1829/4386] 처리완료: 2256.bmp
# [1830/4386] 처리완료: 791.bmp
# [1831/4386] 처리완료: 1234.bmp
# [1832/4386] 처리완료: 1370.bmp
# [1833/4386] 처리완료: 4654.bmp
# ...
# [3790/4386] 처리완료: 1825.bmp
# [3791/4386] 처리완료: 1172.bmp
# [3792/4386] 처리완료: 3222.bmp
# [3793/4386] 처리완료: 452.bmp
# [3794/4386] 처리완료: 3489.bmp
# [3795/4386] 처리완료: 1822.bmp
# [3796/4386] 처리완료: 3141.bmp
# [3797/4386] 처리완료: 1144.bmp
# [3798/4386] 처리완료: 969.bmp
# [3799/4386] 처리완료: 3507.bmp
# [3800/4386] 처리완료: 3212.bmp
# [3801/4386] 처리완료: 4624.bmp
# [3802/4386] 처리완료: 1050.bmp
# [3803/4386] 처리완료: 3723.bmp
# [3804/4386] 처리완료: 271.bmp
# [3805/4386] 처리완료: 2217.bmp
# [3806/4386] 처리완료: 897.bmp
# [3807/4386] 처리완료: 2617.bmp
# [3808/4386] 처리완료: 4566.bmp
# [3809/4386] 처리완료: 260.bmp
# [3810/4386] 처리완료: 2566.bmp
# [3811/4386] 처리완료: 3286.bmp
# [3812/4386] 처리완료: 1677.bmp
# [3813/4386] 처리완료: 1223.bmp
# [3814/4386] 처리완료: 1282.bmp
# [3815/4386] 처리완료: 1106.bmp
# [3816/4386] 처리완료: 2771.bmp
# [3817/4386] 처리완료: 2068.bmp
# [3818/4386] 처리완료: 4952.bmp
# [3819/4386] 처리완료: 640.bmp
# [3820/4386] 처리완료: 4074.bmp
# [3821/4386] 처리완료: 986.bmp
# [3822/4386] 처리완료: 583.bmp
# [3823/4386] 처리완료: 269.bmp
# [3824/4386] 처리완료: 1728.bmp
# [3825/4386] 처리완료: 3760.bmp
# [3826/4386] 처리완료: 1266.bmp
# [3827/4386] 처리완료: 1791.bmp
# [3828/4386] 처리완료: 190.bmp
# [3829/4386] 처리완료: 3338.bmp
# [3830/4386] 처리완료: 1169.bmp
# [3831/4386] 처리완료: 2343.bmp
# [3832/4386] 처리완료: 1065.bmp
# [3833/4386] 처리완료: 4736.bmp
# [3834/4386] 처리완료: 1021.bmp
# [3835/4386] 처리완료: 2628.bmp
# [3836/4386] 처리완료: 752.bmp
# [3837/4386] 처리완료: 4921.bmp
# [3838/4386] 처리완료: 489.bmp
# [3839/4386] 처리완료: 4554.bmp
# [3840/4386] 처리완료: 4177.bmp
# [3841/4386] 처리완료: 4144.bmp
# [3842/4386] 처리완료: 5098.bmp
# [3843/4386] 처리완료: 1594.bmp
# [3844/4386] 처리완료: 4403.bmp
# [3845/4386] 처리완료: 1200.bmp
# [3846/4386] 처리완료: 3466.bmp
# [3847/4386] 처리완료: 3587.bmp
# [3848/4386] 처리완료: 1740.bmp
# [3849/4386] 처리완료: 2622.bmp
# [3850/4386] 처리완료: 2255.bmp
# [3851/4386] 처리완료: 256.bmp
# [3852/4386] 처리완료: 653.bmp
# [3853/4386] 처리완료: 1758.bmp
# [3854/4386] 처리완료: 2281.bmp
# [3855/4386] 처리완료: 4387.bmp
# [3856/4386] 처리완료: 4273.bmp
# [3857/4386] 처리완료: 930.bmp
# [3858/4386] 처리완료: 1366.bmp
# [3859/4386] 처리완료: 1271.bmp
# [3860/4386] 처리완료: 3839.bmp
# [3861/4386] 처리완료: 1197.bmp
# [3862/4386] 처리완료: 3925.bmp
# [3863/4386] 처리완료: 1732.bmp
# [3864/4386] 처리완료: 1449.bmp
# [3865/4386] 처리완료: 4456.bmp
# [3866/4386] 처리완료: 2239.bmp
# [3867/4386] 처리완료: 496.bmp
# [3868/4386] 처리완료: 1590.bmp
# [3869/4386] 처리완료: 638.bmp
# [3870/4386] 처리완료: 3008.bmp
# [3871/4386] 처리완료: 1606.bmp
# [3872/4386] 처리완료: 671.bmp
# [3873/4386] 처리완료: 2687.bmp
# [3874/4386] 처리완료: 2838.bmp
# [3875/4386] 처리완료: 3430.bmp
# [3876/4386] 처리완료: 4799.bmp
# [3877/4386] 처리완료: 265.bmp
# [3878/4386] 처리완료: 785.bmp
# [3879/4386] 처리완료: 2597.bmp
# [3880/4386] 처리완료: 3129.bmp
# [3881/4386] 처리완료: 56.bmp
# [3882/4386] 처리완료: 4012.bmp
# [3883/4386] 처리완료: 423.bmp
# [3884/4386] 처리완료: 2970.bmp
# [3885/4386] 처리완료: 2001.bmp
# [3886/4386] 처리완료: 1948.bmp
# [3887/4386] 처리완료: 1482.bmp
# [3888/4386] 처리완료: 1442.bmp
# [3889/4386] 처리완료: 4605.bmp
# [3890/4386] 처리완료: 2902.bmp
# [3891/4386] 처리완료: 813.bmp
# [3892/4386] 처리완료: 207.bmp
# [3893/4386] 처리완료: 3935.bmp
# [3894/4386] 처리완료: 1872.bmp
# [3895/4386] 처리완료: 2448.bmp
# [3896/4386] 처리완료: 3681.bmp
# [3897/4386] 처리완료: 1615.bmp
# [3898/4386] 처리완료: 4020.bmp
# [3899/4386] 처리완료: 1862.bmp
# [3900/4386] 처리완료: 2694.bmp
# [3901/4386] 처리완료: 3476.bmp
# [3902/4386] 처리완료: 1622.bmp
# [3903/4386] 처리완료: 1752.bmp
# [3904/4386] 처리완료: 3553.bmp
# [3905/4386] 처리완료: 1141.bmp
# [3906/4386] 처리완료: 2788.bmp
# [3907/4386] 처리완료: 3346.bmp
# [3908/4386] 처리완료: 102.bmp
# [3909/4386] 처리완료: 500.bmp
# [3910/4386] 처리완료: 3602.bmp
# [3911/4386] 처리완료: 3296.bmp
# [3912/4386] 처리완료: 1044.bmp
# [3913/4386] 처리완료: 3600.bmp
# [3914/4386] 처리완료: 4826.bmp
# [3915/4386] 처리완료: 3092.bmp
# [3916/4386] 처리완료: 2962.bmp
# [3917/4386] 처리완료: 2741.bmp
# [3918/4386] 처리완료: 1356.bmp
# [3919/4386] 처리완료: 3690.bmp
# [3920/4386] 처리완료: 2578.bmp
# [3921/4386] 처리완료: 3903.bmp
# [3922/4386] 처리완료: 2669.bmp
# [3923/4386] 처리완료: 3358.bmp
# [3924/4386] 처리완료: 4288.bmp
# [3925/4386] 처리완료: 4060.bmp
# [3926/4386] 처리완료: 1509.bmp
# [3927/4386] 처리완료: 839.bmp
# [3928/4386] 처리완료: 759.bmp
# [3929/4386] 처리완료: 2057.bmp
# [3930/4386] 처리완료: 4518.bmp
# [3931/4386] 처리완료: 81.bmp
# [3932/4386] 처리완료: 2494.bmp
# [3933/4386] 처리완료: 18.bmp
# [3934/4386] 처리완료: 2011.bmp
# [3935/4386] 처리완료: 2070.bmp
# [3936/4386] 처리완료: 2942.bmp
# [3937/4386] 처리완료: 3886.bmp
# [3938/4386] 처리완료: 3234.bmp
# [3939/4386] 처리완료: 1576.bmp
# [3940/4386] 처리완료: 4708.bmp
# [3941/4386] 처리완료: 4912.bmp
# [3942/4386] 처리완료: 93.bmp
# [3943/4386] 처리완료: 944.bmp
# [3944/4386] 처리완료: 4829.bmp
# [3945/4386] 처리완료: 5023.bmp
# [3946/4386] 처리완료: 3755.bmp
# [3947/4386] 처리완료: 263.bmp
# [3948/4386] 처리완료: 4025.bmp
# [3949/4386] 처리완료: 1886.bmp
# [3950/4386] 처리완료: 3311.bmp
# [3951/4386] 처리완료: 1693.bmp
# [3952/4386] 처리완료: 3024.bmp
# [3953/4386] 처리완료: 530.bmp
# [3954/4386] 처리완료: 350.bmp
# [3955/4386] 처리완료: 741.bmp
# [3956/4386] 처리완료: 3149.bmp
# [3957/4386] 처리완료: 943.bmp
# [3958/4386] 처리완료: 4039.bmp
# [3959/4386] 처리완료: 1854.bmp
# [3960/4386] 처리완료: 2279.bmp
# [3961/4386] 처리완료: 1479.bmp
# [3962/4386] 처리완료: 3254.bmp
# [3963/4386] 처리완료: 4489.bmp
# [3964/4386] 처리완료: 3637.bmp
# [3965/4386] 처리완료: 2589.bmp
# [3966/4386] 처리완료: 4457.bmp
# [3967/4386] 처리완료: 3822.bmp
# [3968/4386] 처리완료: 3147.bmp
# [3969/4386] 처리완료: 1540.bmp
# [3970/4386] 처리완료: 3750.bmp
# [3971/4386] 처리완료: 1719.bmp
# [3972/4386] 처리완료: 4686.bmp
# [3973/4386] 처리완료: 3974.bmp
# [3974/4386] 처리완료: 4498.bmp
# [3975/4386] 처리완료: 4966.bmp
# [3976/4386] 처리완료: 4569.bmp
# [3977/4386] 처리완료: 4040.bmp
# [3978/4386] 처리완료: 257.bmp
# [3979/4386] 처리완료: 3963.bmp
# [3980/4386] 처리완료: 1935.bmp
# [3981/4386] 처리완료: 1289.bmp
# [3982/4386] 처리완료: 914.bmp
# [3983/4386] 처리완료: 4032.bmp
# [3984/4386] 처리완료: 4568.bmp
# [3985/4386] 처리완료: 3901.bmp
# [3986/4386] 처리완료: 274.bmp
# [3987/4386] 처리완료: 3118.bmp
# [3988/4386] 처리완료: 1618.bmp
# [3989/4386] 처리완료: 1327.bmp
# [3990/4386] 처리완료: 3623.bmp
# [3991/4386] 처리완료: 4702.bmp
# [3992/4386] 처리완료: 456.bmp
# [3993/4386] 처리완료: 3651.bmp
# [3994/4386] 처리완료: 1784.bmp
# [3995/4386] 처리완료: 2913.bmp
# [3996/4386] 처리완료: 4998.bmp
# [3997/4386] 처리완료: 2293.bmp
# [3998/4386] 처리완료: 248.bmp
# [3999/4386] 처리완료: 1209.bmp
# [4000/4386] 처리완료: 4233.bmp
# [4001/4386] 처리완료: 4308.bmp
# [4002/4386] 처리완료: 1911.bmp
# [4003/4386] 처리완료: 1736.bmp
# [4004/4386] 처리완료: 3315.bmp
# [4005/4386] 처리완료: 1525.bmp
# [4006/4386] 처리완료: 2346.bmp
# [4007/4386] 처리완료: 279.bmp
# [4008/4386] 처리완료: 3473.bmp
# [4009/4386] 처리완료: 4167.bmp
# [4010/4386] 처리완료: 4270.bmp
# [4011/4386] 처리완료: 3411.bmp
# [4012/4386] 처리완료: 80.bmp
# [4013/4386] 처리완료: 575.bmp
# [4014/4386] 처리완료: 807.bmp
# [4015/4386] 처리완료: 2848.bmp
# [4016/4386] 처리완료: 2390.bmp
# [4017/4386] 처리완료: 861.bmp
# [4018/4386] 처리완료: 1439.bmp
# [4019/4386] 처리완료: 2391.bmp
# [4020/4386] 처리완료: 3142.bmp
# [4021/4386] 처리완료: 122.bmp
# [4022/4386] 처리완료: 3467.bmp
# [4023/4386] 처리완료: 2208.bmp
# [4024/4386] 처리완료: 3274.bmp
# [4025/4386] 처리완료: 3194.bmp
# [4026/4386] 처리완료: 2079.bmp
# [4027/4386] 처리완료: 1624.bmp
# [4028/4386] 처리완료: 3133.bmp
# [4029/4386] 처리완료: 945.bmp
# [4030/4386] 처리완료: 734.bmp
# [4031/4386] 처리완료: 252.bmp
# [4032/4386] 처리완료: 85.bmp
# [4033/4386] 처리완료: 2588.bmp
# [4034/4386] 처리완료: 2083.bmp
# [4035/4386] 처리완료: 518.bmp
# [4036/4386] 처리완료: 3878.bmp
# [4037/4386] 처리완료: 137.bmp
# [4038/4386] 처리완료: 3590.bmp
# [4039/4386] 처리완료: 4235.bmp
# [4040/4386] 처리완료: 4415.bmp
# [4041/4386] 처리완료: 3526.bmp
# [4042/4386] 처리완료: 926.bmp
# [4043/4386] 처리완료: 4709.bmp
# [4044/4386] 처리완료: 4312.bmp
# [4045/4386] 처리완료: 4984.bmp
# [4046/4386] 처리완료: 2871.bmp
# [4047/4386] 처리완료: 958.bmp
# [4048/4386] 처리완료: 4271.bmp
# [4049/4386] 처리완료: 1733.bmp
# [4050/4386] 처리완료: 3678.bmp
# [4051/4386] 처리완료: 4197.bmp
# [4052/4386] 처리완료: 1787.bmp
# [4053/4386] 처리완료: 1658.bmp
# [4054/4386] 처리완료: 3555.bmp
# [4055/4386] 처리완료: 889.bmp
# [4056/4386] 처리완료: 2433.bmp
# [4057/4386] 처리완료: 2206.bmp
# [4058/4386] 처리완료: 497.bmp
# [4059/4386] 처리완료: 2157.bmp
# [4060/4386] 처리완료: 4864.bmp
# [4061/4386] 처리완료: 1133.bmp
# [4062/4386] 처리완료: 966.bmp
# [4063/4386] 처리완료: 3772.bmp
# [4064/4386] 처리완료: 4259.bmp
# [4065/4386] 처리완료: 3862.bmp
# [4066/4386] 처리완료: 567.bmp
# [4067/4386] 처리완료: 330.bmp
# [4068/4386] 처리완료: 3433.bmp
# [4069/4386] 처리완료: 1961.bmp
# [4070/4386] 처리완료: 1744.bmp
# [4071/4386] 처리완료: 3973.bmp
# [4072/4386] 처리완료: 1708.bmp
# [4073/4386] 처리완료: 4121.bmp
# [4074/4386] 처리완료: 66.bmp
# [4075/4386] 처리완료: 483.bmp
# [4076/4386] 처리완료: 404.bmp
# [4077/4386] 처리완료: 4904.bmp
# [4078/4386] 처리완료: 1436.bmp
# [4079/4386] 처리완료: 2487.bmp
# [4080/4386] 처리완료: 3447.bmp
# [4081/4386] 처리완료: 4474.bmp
# [4082/4386] 처리완료: 3634.bmp
# [4083/4386] 처리완료: 1876.bmp
# [4084/4386] 처리완료: 4230.bmp
# [4085/4386] 처리완료: 528.bmp
# [4086/4386] 처리완료: 3696.bmp
# [4087/4386] 처리완료: 418.bmp
# [4088/4386] 처리완료: 1857.bmp
# [4089/4386] 처리완료: 984.bmp
# [4090/4386] 처리완료: 74.bmp
# [4091/4386] 처리완료: 4606.bmp
# [4092/4386] 처리완료: 130.bmp
# [4093/4386] 처리완료: 2168.bmp
# [4094/4386] 처리완료: 3464.bmp
# [4095/4386] 처리완료: 5066.bmp
# [4096/4386] 처리완료: 1167.bmp
# [4097/4386] 처리완료: 2637.bmp
# [4098/4386] 처리완료: 2933.bmp
# [4099/4386] 처리완료: 4413.bmp
# [4100/4386] 처리완료: 1656.bmp
# [4101/4386] 처리완료: 3258.bmp
# [4102/4386] 처리완료: 4953.bmp
# [4103/4386] 처리완료: 1884.bmp
# [4104/4386] 처리완료: 3060.bmp
# [4105/4386] 처리완료: 3126.bmp
# [4106/4386] 처리완료: 220.bmp
# [4107/4386] 처리완료: 3207.bmp
# [4108/4386] 처리완료: 594.bmp
# [4109/4386] 처리완료: 145.bmp
# [4110/4386] 처리완료: 2556.bmp
# [4111/4386] 처리완료: 1828.bmp
# [4112/4386] 처리완료: 1893.bmp
# [4113/4386] 처리완료: 2274.bmp
# [4114/4386] 처리완료: 1895.bmp
# [4115/4386] 처리완료: 2655.bmp
# [4116/4386] 처리완료: 4800.bmp
# [4117/4386] 처리완료: 4373.bmp
# [4118/4386] 처리완료: 5082.bmp
# [4119/4386] 처리완료: 94.bmp
# [4120/4386] 처리완료: 964.bmp
# [4121/4386] 처리완료: 2534.bmp
# [4122/4386] 처리완료: 760.bmp
# [4123/4386] 처리완료: 5.bmp
# [4124/4386] 처리완료: 4752.bmp
# [4125/4386] 처리완료: 3955.bmp
# [4126/4386] 처리완료: 1302.bmp
# [4127/4386] 처리완료: 1314.bmp
# [4128/4386] 처리완료: 2575.bmp
# [4129/4386] 처리완료: 868.bmp
# [4130/4386] 처리완료: 3324.bmp
# [4131/4386] 처리완료: 758.bmp
# [4132/4386] 처리완료: 4821.bmp
# [4133/4386] 처리완료: 957.bmp
# [4134/4386] 처리완료: 2810.bmp
# [4135/4386] 처리완료: 3175.bmp
# [4136/4386] 처리완료: 3316.bmp
# [4137/4386] 처리완료: 261.bmp
# [4138/4386] 처리완료: 1447.bmp
# [4139/4386] 처리완료: 2814.bmp
# [4140/4386] 처리완료: 2096.bmp
# [4141/4386] 처리완료: 1888.bmp
# [4142/4386] 처리완료: 5077.bmp
# [4143/4386] 처리완료: 4617.bmp
# [4144/4386] 처리완료: 3006.bmp
# [4145/4386] 처리완료: 3395.bmp
# [4146/4386] 처리완료: 1824.bmp
# [4147/4386] 처리완료: 4317.bmp
# [4148/4386] 처리완료: 2545.bmp
# [4149/4386] 처리완료: 3677.bmp
# [4150/4386] 처리완료: 4684.bmp
# [4151/4386] 처리완료: 815.bmp
# [4152/4386] 처리완료: 3050.bmp
# [4153/4386] 처리완료: 2021.bmp
# [4154/4386] 처리완료: 141.bmp
# [4155/4386] 처리완료: 1365.bmp
# [4156/4386] 처리완료: 4155.bmp
# [4157/4386] 처리완료: 320.bmp
# [4158/4386] 처리완료: 16.bmp
# [4159/4386] 처리완료: 5044.bmp
# [4160/4386] 처리완료: 4647.bmp
# [4161/4386] 처리완료: 345.bmp
# [4162/4386] 처리완료: 4793.bmp
# [4163/4386] 처리완료: 2965.bmp
# [4164/4386] 처리완료: 1796.bmp
# [4165/4386] 처리완료: 1661.bmp
# [4166/4386] 처리완료: 4266.bmp
# [4167/4386] 처리완료: 1572.bmp
# [4168/4386] 처리완료: 2808.bmp
# [4169/4386] 처리완료: 72.bmp
# [4170/4386] 처리완료: 967.bmp
# [4171/4386] 처리완료: 1946.bmp
# [4172/4386] 처리완료: 1519.bmp
# [4173/4386] 처리완료: 2155.bmp
# [4174/4386] 처리완료: 2276.bmp
# [4175/4386] 처리완료: 4094.bmp
# [4176/4386] 처리완료: 4526.bmp
# [4177/4386] 처리완료: 3917.bmp
# [4178/4386] 처리완료: 3166.bmp
# [4179/4386] 처리완료: 44.bmp
# [4180/4386] 처리완료: 4973.bmp
# [4181/4386] 처리완료: 2000.bmp
# [4182/4386] 처리완료: 811.bmp
# [4183/4386] 처리완료: 96.bmp
# [4184/4386] 처리완료: 2565.bmp
# [4185/4386] 처리완료: 1090.bmp
# [4186/4386] 처리완료: 3216.bmp
# [4187/4386] 처리완료: 1653.bmp
# [4188/4386] 처리완료: 2888.bmp
# [4189/4386] 처리완료: 3999.bmp
# [4190/4386] 처리완료: 1816.bmp
# [4191/4386] 처리완료: 2749.bmp
# [4192/4386] 처리완료: 484.bmp
# [4193/4386] 처리완료: 3471.bmp
# [4194/4386] 처리완료: 2360.bmp
# [4195/4386] 처리완료: 2806.bmp
# [4196/4386] 처리완료: 144.bmp
# [4197/4386] 처리완료: 3046.bmp
# [4198/4386] 처리완료: 4522.bmp
# [4199/4386] 처리완료: 4126.bmp
# [4200/4386] 처리완료: 3332.bmp
# [4201/4386] 처리완료: 894.bmp
# [4202/4386] 처리완료: 2173.bmp
# [4203/4386] 처리완료: 4101.bmp
# [4204/4386] 처리완료: 4160.bmp
# [4205/4386] 처리완료: 4662.bmp
# [4206/4386] 처리완료: 4687.bmp
# [4207/4386] 처리완료: 3916.bmp
# [4208/4386] 처리완료: 2486.bmp
# [4209/4386] 처리완료: 2772.bmp
# [4210/4386] 처리완료: 4227.bmp
# [4211/4386] 처리완료: 2695.bmp
# [4212/4386] 처리완료: 3295.bmp
# [4213/4386] 처리완료: 2425.bmp
# [4214/4386] 처리완료: 2471.bmp
# [4215/4386] 처리완료: 4314.bmp
# [4216/4386] 처리완료: 132.bmp
# [4217/4386] 처리완료: 3172.bmp
# [4218/4386] 처리완료: 381.bmp
# [4219/4386] 처리완료: 210.bmp
# [4220/4386] 처리완료: 4764.bmp
# [4221/4386] 처리완료: 1014.bmp
# [4222/4386] 처리완료: 4452.bmp
# [4223/4386] 처리완료: 854.bmp
# [4224/4386] 처리완료: 3396.bmp
# [4225/4386] 처리완료: 3384.bmp
# [4226/4386] 처리완료: 1390.bmp
# [4227/4386] 처리완료: 3621.bmp
# [4228/4386] 처리완료: 1288.bmp
# [4229/4386] 처리완료: 4794.bmp
# [4230/4386] 처리완료: 2922.bmp
# [4231/4386] 처리완료: 2394.bmp
# [4232/4386] 처리완료: 312.bmp
# [4233/4386] 처리완료: 1161.bmp
# [4234/4386] 처리완료: 3349.bmp
# [4235/4386] 처리완료: 2329.bmp
# [4236/4386] 처리완료: 2504.bmp
# [4237/4386] 처리완료: 3830.bmp
# [4238/4386] 처리완료: 4602.bmp
# [4239/4386] 처리완료: 1154.bmp
# [4240/4386] 처리완료: 3747.bmp
# [4241/4386] 처리완료: 2758.bmp
# [4242/4386] 처리완료: 406.bmp
# [4243/4386] 처리완료: 4726.bmp
# [4244/4386] 처리완료: 3942.bmp
# [4245/4386] 처리완료: 4161.bmp
# [4246/4386] 처리완료: 1023.bmp
# [4247/4386] 처리완료: 4104.bmp
# [4248/4386] 처리완료: 4633.bmp
# [4249/4386] 처리완료: 88.bmp
# [4250/4386] 처리완료: 2216.bmp
# [4251/4386] 처리완료: 1713.bmp
# [4252/4386] 처리완료: 3695.bmp
# [4253/4386] 처리완료: 173.bmp
# [4254/4386] 처리완료: 2927.bmp
# [4255/4386] 처리완료: 1466.bmp
# [4256/4386] 처리완료: 4071.bmp
# [4257/4386] 처리완료: 2012.bmp
# [4258/4386] 처리완료: 826.bmp
# [4259/4386] 처리완료: 1962.bmp
# [4260/4386] 처리완료: 911.bmp
# [4261/4386] 처리완료: 4202.bmp
# [4262/4386] 처리완료: 3241.bmp
# [4263/4386] 처리완료: 1996.bmp
# [4264/4386] 처리완료: 834.bmp
# [4265/4386] 처리완료: 2438.bmp
# [4266/4386] 처리완료: 2263.bmp
# [4267/4386] 처리완료: 4544.bmp
# [4268/4386] 처리완료: 1565.bmp
# [4269/4386] 처리완료: 4008.bmp
# [4270/4386] 처리완료: 3853.bmp
# [4271/4386] 처리완료: 1024.bmp
# [4272/4386] 처리완료: 3301.bmp
# [4273/4386] 처리완료: 4492.bmp
# [4274/4386] 처리완료: 994.bmp
# [4275/4386] 처리완료: 4450.bmp
# [4276/4386] 처리완료: 4773.bmp
# [4277/4386] 처리완료: 613.bmp
# [4278/4386] 처리완료: 3765.bmp
# [4279/4386] 처리완료: 5038.bmp
# [4280/4386] 처리완료: 1262.bmp
# [4281/4386] 처리완료: 709.bmp
# [4282/4386] 처리완료: 4622.bmp
# [4283/4386] 처리완료: 4138.bmp
# [4284/4386] 처리완료: 4444.bmp
# [4285/4386] 처리완료: 2091.bmp
# [4286/4386] 처리완료: 3704.bmp
# [4287/4386] 처리완료: 4471.bmp
# [4288/4386] 처리완료: 746.bmp
# [4289/4386] 처리완료: 5015.bmp
# [4290/4386] 처리완료: 4432.bmp
# [4291/4386] 처리완료: 270.bmp
# [4292/4386] 처리완료: 240.bmp
# [4293/4386] 처리완료: 605.bmp
# [4294/4386] 처리완료: 1182.bmp
# [4295/4386] 처리완료: 409.bmp
# [4296/4386] 처리완료: 4562.bmp
# [4297/4386] 처리완료: 4876.bmp
# [4298/4386] 처리완료: 2584.bmp
# [4299/4386] 처리완료: 3398.bmp
# [4300/4386] 처리완료: 4157.bmp
# [4301/4386] 처리완료: 2014.bmp
# [4302/4386] 처리완료: 3515.bmp
# [4303/4386] 처리완료: 1761.bmp
# [4304/4386] 처리완료: 2855.bmp
# [4305/4386] 처리완료: 2801.bmp
# [4306/4386] 처리완료: 769.bmp
# [4307/4386] 처리완료: 3618.bmp
# [4308/4386] 처리완료: 3002.bmp
# [4309/4386] 처리완료: 3730.bmp
# [4310/4386] 처리완료: 3000.bmp
# [4311/4386] 처리완료: 3749.bmp
# [4312/4386] 처리완료: 874.bmp
# [4313/4386] 처리완료: 1208.bmp
# [4314/4386] 처리완료: 1520.bmp
# [4315/4386] 처리완료: 3687.bmp
# [4316/4386] 처리완료: 1409.bmp
# [4317/4386] 처리완료: 3263.bmp
# [4318/4386] 처리완료: 2324.bmp
# [4319/4386] 처리완료: 42.bmp
# [4320/4386] 처리완료: 4013.bmp
# [4321/4386] 처리완료: 1185.bmp
# [4322/4386] 처리완료: 3082.bmp
# [4323/4386] 처리완료: 3330.bmp
# [4324/4386] 처리완료: 506.bmp
# [4325/4386] 처리완료: 2085.bmp
# [4326/4386] 처리완료: 1304.bmp
# [4327/4386] 처리완료: 1766.bmp
# [4328/4386] 처리완료: 1298.bmp
# [4329/4386] 처리완료: 1084.bmp
# [4330/4386] 처리완료: 3383.bmp
# [4331/4386] 처리완료: 615.bmp
# [4332/4386] 처리완료: 908.bmp
# [4333/4386] 처리완료: 4265.bmp
# [4334/4386] 처리완료: 3261.bmp
# [4335/4386] 처리완료: 795.bmp
# [4336/4386] 처리완료: 1325.bmp
# [4337/4386] 처리완료: 4886.bmp
# [4338/4386] 처리완료: 4001.bmp
# [4339/4386] 처리완료: 5096.bmp
# [4340/4386] 처리완료: 292.bmp
# [4341/4386] 처리완료: 3431.bmp
# [4342/4386] 처리완료: 3619.bmp
# [4343/4386] 처리완료: 4042.bmp
# [4344/4386] 처리완료: 4505.bmp
# [4345/4386] 처리완료: 4803.bmp
# [4346/4386] 처리완료: 1265.bmp
# [4347/4386] 처리완료: 43.bmp
# [4348/4386] 처리완료: 4974.bmp
# [4349/4386] 처리완료: 2194.bmp
# [4350/4386] 처리완료: 2762.bmp
# [4351/4386] 처리완료: 241.bmp
# [4352/4386] 처리완료: 509.bmp
# [4353/4386] 처리완료: 2013.bmp
# [4354/4386] 처리완료: 364.bmp
# [4355/4386] 처리완료: 3616.bmp
# [4356/4386] 처리완료: 1775.bmp
# [4357/4386] 처리완료: 4159.bmp
# [4358/4386] 처리완료: 76.bmp
# [4359/4386] 처리완료: 3040.bmp
# [4360/4386] 처리완료: 588.bmp
# [4361/4386] 처리완료: 609.bmp
# [4362/4386] 처리완료: 3015.bmp
# [4363/4386] 처리완료: 895.bmp
# [4364/4386] 처리완료: 1602.bmp
# [4365/4386] 처리완료: 2200.bmp
# [4366/4386] 처리완료: 4926.bmp
# [4367/4386] 처리완료: 1856.bmp
# [4368/4386] 처리완료: 1782.bmp
# [4369/4386] 처리완료: 3025.bmp
# [4370/4386] 처리완료: 17.bmp
# [4371/4386] 처리완료: 599.bmp
# [4372/4386] 처리완료: 3949.bmp
# [4373/4386] 처리완료: 2711.bmp
# [4374/4386] 처리완료: 3102.bmp
# [4375/4386] 처리완료: 1373.bmp
# [4376/4386] 처리완료: 1750.bmp
# [4377/4386] 처리완료: 308.bmp
# [4378/4386] 처리완료: 3418.bmp
# [4379/4386] 처리완료: 3773.bmp
# [4380/4386] 처리완료: 3657.bmp
# [4381/4386] 처리완료: 1861.bmp
# [4382/4386] 처리완료: 9.bmp
# [4383/4386] 처리완료: 1277.bmp
# [4384/4386] 처리완료: 2517.bmp
# [4385/4386] 처리완료: 1511.bmp
# [4386/4386] 처리완료: 1788.bmp
# 모든 이미지 처리가 완료되었습니다.

# %%
import os
import shutil

# 소스 폴더와 대상 폴더 경로
src_folder = '/home/ec2-user/SageMaker/data/edge_NG_156'
dst_folder = '/home/ec2-user/SageMaker/data/edge_NG_143'

# 복사할 파일 리스트
files_to_copy = [
    'edge_971.bmp', 'edge_4439.bmp', 'edge_4447.bmp', 'edge_2659.bmp', 
    'edge_2667.bmp', 'edge_2675.bmp', 'edge_883.bmp', 'edge_4563.bmp',
    'edge_4875.bmp', 'edge_1755.bmp', 'edge_4987.bmp', 'edge_2642.bmp',
    'edge_4683.bmp', 'edge_4748.bmp', 'edge_4597.bmp', 'edge_4588.bmp',
    'edge_4322.bmp', 'edge_4377.bmp', 'edge_4383.bmp', 'edge_4345.bmp',
    'edge_4343.bmp', 'edge_4612.bmp', 'edge_4347.bmp', 'edge_4362.bmp',
    'edge_3940.bmp', 'edge_4306.bmp', 'edge_4483.bmp', 'edge_4491.bmp'
]

# 파일 복사
copied_count = 0
for filename in files_to_copy:
    src_path = os.path.join(src_folder, filename)
    dst_path = os.path.join(dst_folder, filename)
    if os.path.exists(src_path):
        shutil.copy2(src_path, dst_path)
        print(f"복사됨: {filename}")
        copied_count += 1
    else:
        print(f"파일을 찾을 수 없음: {filename}")

print(f"\n복사 완료! 총 {copied_count}개 파일이 복사되었습니다.")

# %%
from skimage.feature import graycomatrix, graycoprops
from sklearn.manifold import TSNE

def load_images_from_folder(folder_path):
    """폴더에서 이미지를 로드합니다."""
    images = []
    valid_extensions = ['.bmp', '.jpg', '.jpeg', '.png']
    
    for filename in os.listdir(folder_path):
        if any(filename.lower().endswith(ext) for ext in valid_extensions):
            image_path = os.path.join(folder_path, filename)
            img = cv2.imread(image_path)
            if img is not None:
                images.append({
                    'image': img,
                    'filename': filename
                })
    
    return images

def visualize_plots(images, predictions, probabilities, filenames):
    """결과 시각화 함수"""
    # 클래스별 예측 개수 시각화
    plt.figure(figsize=(12, 5))
    
    # 1. 클래스별 분포 그래프
    plt.subplot(121)
    classes = ['dent', 'torn', 'bubble', 'foreignsub']
    class_counts = [np.sum(predictions == i) for i in range(len(classes))]
    
    plt.bar(classes, class_counts)
    plt.title('Distribution of Predicted Classes')
    plt.ylabel('Number of Images')
    plt.xticks(rotation=45)
    
    # 2. t-SNE를 사용한 군집 시각화
    plt.subplot(122)
    tsne = TSNE(n_components=2, random_state=42)
    features_2d = tsne.fit_transform(probabilities)
    
    colors = ['red', 'blue', 'green', 'purple']
    for i, class_name in enumerate(classes):
        mask = predictions == i
        plt.scatter(features_2d[mask, 0], features_2d[mask, 1], 
                   c=colors[i], label=class_name, alpha=0.6)
    
    plt.title('Clustering Visualization')
    plt.legend()
    plt.tight_layout()
    plt.show()
    
    return {
        'class_distribution': dict(zip(classes, class_counts)),
        'clustering': features_2d
    }




def visualize_results(images, predictions, probabilities, filenames):
    """결과를 시각화합니다. 한 줄에 6개의 이미지를 표시합니다."""
    categories = ['dent', 'torn', 'bubble', 'foreignsub']
    n_images = len(images)
    n_cols = 6
    n_rows = math.ceil(n_images / n_cols)
    
    # 결과를 저장할 리스트 생성
    results = []
    
    # 이미지 그리드 생성
    fig = plt.figure(figsize=(20, 3*n_rows))
    for i, img_data in enumerate(images):
        plt.subplot(n_rows, n_cols, i + 1)
        plt.imshow(img_data['image'], cmap='gray')
        
        # 예측 결과 및 신뢰도
        pred_category = categories[predictions[i]]
        prob = probabilities[i][predictions[i]] * 100
        
        # 결과 저장
        results.append({
            'file': filenames[i],
            'prediction': pred_category,
            'confidence': prob
        })
        
        # 타이틀에 파일명과 예측 결과 표시
        plt.title(f"{filenames[i]}\n{pred_category}\n{prob:.1f}%", 
                 fontsize=8, pad=5)
        plt.axis('off')
    
    plt.tight_layout()
    plt.show()
    
    # 예측 결과 출력
    print("\n예측 결과:")
    for r in results:
        print(f"File: {r['file']:<20} Prediction: {r['prediction']:<12} Confidence: {r['confidence']:.1f}%")
    
    return results

# %%
import os
import shutil
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.semi_supervised import LabelPropagation
from sklearn.metrics.pairwise import rbf_kernel
import cv2
import math
from skimage.feature import graycomatrix, graycoprops
from sklearn.manifold import TSNE

def create_training_data(images, defect_images):
    """학습 데이터를 생성합니다."""
    features = []
    labels = []
    filenames = []
    categories = {'dent': 0, 'torn': 1, 'bubble': 2, 'foreignsub': 3}
    
    # 레이블이 있는 데이터와 없는 데이터 구분
    labeled_files = {d['file'].lower(): d['category'] for d in defect_images}
    
    labeled_count = 0
    for img_data in images:
        features.append(extract_features(img_data['image']))
        filenames.append(img_data['filename'])
        
        # 파일명을 소문자로 변환하여 비교
        if img_data['filename'].lower() in labeled_files:
            labels.append(categories[labeled_files[img_data['filename'].lower()]])
            labeled_count += 1
        else:
            labels.append(-1)
    
    print(f"Found {labeled_count} labeled images out of {len(images)} total images")
    
    if labeled_count == 0:
        raise ValueError("No labeled data found! Please check if the image filenames match with defect_images.")
    
    return np.array(features), np.array(labels), filenames

def extract_features(image):
    """특징 추출 함수 개선"""
    features = []
    
    # 1. 엣지 검출 강화
    edges = cv2.Canny(image, 50, 150)
    edge_density = np.mean(edges) / 255.0
    
    # 2. 로컬 컨트라스트 특징
    local_std = np.std(image.astype(float))
    
    # 3. 텍스처 특징 추출
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY) if len(image.shape) == 3 else image
    glcm = graycomatrix(gray, [1], [0, np.pi/4, np.pi/2, 3*np.pi/4])
    contrast = graycoprops(glcm, 'contrast')[0]
    dissimilarity = graycoprops(glcm, 'dissimilarity')[0]
    
    # 4. 블롭 검출
    params = cv2.SimpleBlobDetector_Params()
    params.minThreshold = 10
    params.maxThreshold = 200
    params.filterByArea = True
    params.minArea = 20
    detector = cv2.SimpleBlobDetector_create(params)
    keypoints = detector.detect(gray)
    blob_count = len(keypoints)
    
    # 5. 엣지 방향성 분석
    sobelx = cv2.Sobel(gray, cv2.CV_64F, 1, 0, ksize=3)
    sobely = cv2.Sobel(gray, cv2.CV_64F, 0, 1, ksize=3)
    edge_angles = np.arctan2(sobely, sobelx)
    angle_hist, _ = np.histogram(edge_angles, bins=8, range=(-np.pi, np.pi))
    
    # 특징 벡터 구성
    features.extend([
        edge_density,
        local_std,
        *contrast,
        *dissimilarity,
        blob_count,
        *angle_hist
    ])
    
    return np.array(features)

def train_semi_supervised(features, labels):
    """반지도 학습 모델 개선"""
    # 데이터 증강
    augmented_features = []
    augmented_labels = []
    for i, (feat, label) in enumerate(zip(features, labels)):
        if label != -1:  # 레이블이 있는 데이터만 증강
            noise = np.random.normal(0, 0.1, feat.shape)
            augmented_features.append(feat + noise)
            augmented_labels.append(label)
    
    features = np.vstack([features, augmented_features])
    labels = np.concatenate([labels, augmented_labels])
    
    # 모델 파라미터 조정
    model = LabelPropagation(
        kernel='rbf',
        gamma=3,  # gamma 값 조정
        max_iter=2000,
        tol=1e-6
    )
    
    # 모델 학습
    model.fit(features, labels)
    
    # 예측 및 확률 계산
    predictions = model.predict(features)
    probabilities = model.predict_proba(features)
    
    return predictions, probabilities


def compute_class_weights(labels):
    """클래스 불균형 처리를 위한 가중치 계산"""
    unique_labels = np.unique(labels[labels != -1])
    class_counts = np.array([np.sum(labels == label) for label in unique_labels])
    weights = 1.0 / class_counts
    weights = weights / np.sum(weights) * len(unique_labels)
    return dict(zip(unique_labels, weights))

def main(folder_path, defect_images):
    """메인 실행 함수"""
    print("Loading images...")
    images = load_images_from_folder(folder_path)
    
    print(f"Loaded {len(images)} images")
    print("\nImage filenames in folder:")
    for img in images[:5]:  # 처음 5개 파일명만 출력
        print(f"- {img['filename']}")
    
    print("\nLabeled images we're looking for:")
    for defect in defect_images:
        print(f"- {defect['file']} ({defect['category']})")
    
    print("\nExtracting features...")
    features, labels, filenames = create_training_data(images, defect_images)
    
    print("\nStandardizing features...")
    scaler = StandardScaler()
    scaled_features = scaler.fit_transform(features)
    
    print("Reducing dimensionality...")
    pca = PCA(n_components=min(20, scaled_features.shape[1]))
    reduced_features = pca.fit_transform(scaled_features)
    print(f"Reduced features shape: {reduced_features.shape}")
    
    print("\nTraining semi-supervised model...")
    predictions, probabilities = train_semi_supervised(reduced_features, labels)
    
    print("Visualizing plots...")
    results = visualize_plots(images, predictions, probabilities, filenames)
    
    print("Visualizing results...")
    results = visualize_results(images, predictions, probabilities, filenames)
    
    return results


if __name__ == "__main__":
    folder_path = '/home/ec2-user/SageMaker/data/edge_NG_143_add_28'
    defect_images = [
    # dent 예시 이미지들
    {'file': 'edge_830.bmp', 'category': 'dent'},
    {'file': 'edge_733.bmp', 'category': 'dent'},
    {'file': 'edge_4447.bmp', 'category': 'dent'},
    {'file': 'edge_2659.bmp', 'category': 'dent'},
    {'file': 'edge_725.bmp', 'category': 'dent'},
    {'file': 'edge_2675.bmp', 'category': 'dent'},
    
    # torn 예시 이미지들
    {'file': 'edge_997.bmp', 'category': 'torn'},
    {'file': 'edge_1102.bmp', 'category': 'torn'},
    {'file': 'edge_988.bmp', 'category': 'torn'},
    {'file': 'edge_856.bmp', 'category': 'torn'},
    {'file': 'edge_4987.bmp', 'category': 'torn'},
    {'file': 'edge_2642.bmp', 'category': 'torn'},
    {'file': 'edge_4683.bmp', 'category': 'torn'},
    
    # bubble 예시 이미지들
    {'file': 'edge_4748.bmp', 'category': 'bubble'},
    {'file': 'edge_4597.bmp', 'category': 'bubble'},
    {'file': 'edge_4588.bmp', 'category': 'bubble'},
    {'file': 'edge_4322.bmp', 'category': 'bubble'},
    {'file': 'edge_4377.bmp', 'category': 'bubble'},
    {'file': 'edge_4383.bmp', 'category': 'bubble'},
    {'file': 'edge_4345.bmp', 'category': 'bubble'},
    {'file': 'edge_4343.bmp', 'category': 'bubble'},
    {'file': 'edge_4612.bmp', 'category': 'bubble'},
    {'file': 'edge_4347.bmp', 'category': 'bubble'},
    {'file': 'edge_4362.bmp', 'category': 'bubble'},
    
    # foreignsub 예시 이미지들
    {'file': 'edge_3940.bmp', 'category': 'foreignsub'},
    {'file': 'edge_4306.bmp', 'category': 'foreignsub'},
    {'file': 'edge_4483.bmp', 'category': 'foreignsub'},
    {'file': 'edge_4491.bmp', 'category': 'foreignsub'},
]
    main(folder_path, defect_images)

# %%
import pandas as pd
import re

# Create lists to store the data
files = []
predictions = []

# Get the actual data from the document_content
data = '''File: edge_4362.bmp        Prediction: bubble       Confidence: 100.0%
File: edge_1172.bmp        Prediction: bubble       Confidence: 71.5%
File: edge_4825.bmp        Prediction: bubble       Confidence: 60.2%
File: edge_997.bmp         Prediction: torn         Confidence: 99.6%
File: edge_856.bmp         Prediction: torn         Confidence: 100.0%
File: edge_4937.bmp        Prediction: bubble       Confidence: 50.5%
File: edge_4923.bmp        Prediction: bubble       Confidence: 62.9%
File: edge_2675.bmp        Prediction: dent         Confidence: 100.0%
File: edge_4860.bmp        Prediction: bubble       Confidence: 68.3%
File: edge_4880.bmp        Prediction: bubble       Confidence: 55.6%
File: edge_725.bmp         Prediction: dent         Confidence: 96.7%
File: edge_4936.bmp        Prediction: bubble       Confidence: 54.0%
File: edge_998.bmp         Prediction: torn         Confidence: 80.0%
File: edge_4848.bmp        Prediction: bubble       Confidence: 60.7%
File: edge_988.bmp         Prediction: torn         Confidence: 94.6%
File: edge_4862.bmp        Prediction: bubble       Confidence: 60.5%
File: edge_4985.bmp        Prediction: bubble       Confidence: 65.3%
File: edge_4861.bmp        Prediction: bubble       Confidence: 63.9%
File: edge_4845.bmp        Prediction: bubble       Confidence: 60.4%
File: edge_4946.bmp        Prediction: bubble       Confidence: 49.7%
File: edge_886.bmp         Prediction: bubble       Confidence: 78.0%
File: edge_4892.bmp        Prediction: bubble       Confidence: 53.7%
File: edge_5194.bmp        Prediction: torn         Confidence: 61.1%
File: edge_4859.bmp        Prediction: torn         Confidence: 42.5%
File: edge_757.bmp         Prediction: torn         Confidence: 66.5%
File: edge_4563.bmp        Prediction: bubble       Confidence: 47.5%
File: edge_4905.bmp        Prediction: bubble       Confidence: 59.0%
File: edge_4894.bmp        Prediction: bubble       Confidence: 55.0%
File: edge_4906.bmp        Prediction: bubble       Confidence: 69.5%
File: edge_996.bmp         Prediction: bubble       Confidence: 66.9%
File: edge_4840.bmp        Prediction: bubble       Confidence: 60.0%
File: edge_4855.bmp        Prediction: bubble       Confidence: 62.7%
File: edge_4931.bmp        Prediction: bubble       Confidence: 60.2%
File: edge_4929.bmp        Prediction: bubble       Confidence: 58.7%
File: edge_4832.bmp        Prediction: bubble       Confidence: 59.8%
File: edge_4844.bmp        Prediction: bubble       Confidence: 60.3%
File: edge_4893.bmp        Prediction: bubble       Confidence: 53.7%
File: edge_830.bmp         Prediction: dent         Confidence: 99.8%
File: edge_4748.bmp        Prediction: bubble       Confidence: 97.9%
File: edge_4947.bmp        Prediction: bubble       Confidence: 55.5%
File: edge_4841.bmp        Prediction: bubble       Confidence: 59.0%
File: edge_4913.bmp        Prediction: bubble       Confidence: 58.3%
File: edge_4907.bmp        Prediction: torn         Confidence: 40.7%
File: edge_4976.bmp        Prediction: bubble       Confidence: 59.8%
File: edge_4920.bmp        Prediction: bubble       Confidence: 73.4%
File: edge_4872.bmp        Prediction: bubble       Confidence: 64.5%
File: edge_4824.bmp        Prediction: bubble       Confidence: 79.7%
File: edge_4987.bmp        Prediction: torn         Confidence: 94.5%
File: edge_4930.bmp        Prediction: bubble       Confidence: 49.5%
File: edge_4483.bmp        Prediction: foreignsub   Confidence: 88.5%
File: edge_4306.bmp        Prediction: foreignsub   Confidence: 99.8%
File: edge_4865.bmp        Prediction: bubble       Confidence: 58.0%
File: edge_4597.bmp        Prediction: bubble       Confidence: 100.0%
File: edge_763.bmp         Prediction: dent         Confidence: 90.1%
File: edge_4839.bmp        Prediction: bubble       Confidence: 67.0%
File: edge_4899.bmp        Prediction: bubble       Confidence: 67.9%
File: edge_4857.bmp        Prediction: bubble       Confidence: 60.4%
File: edge_4875.bmp        Prediction: bubble       Confidence: 95.8%
File: edge_772.bmp         Prediction: dent         Confidence: 54.8%
File: edge_4863.bmp        Prediction: bubble       Confidence: 62.8%
File: edge_4928.bmp        Prediction: bubble       Confidence: 50.8%
File: edge_4383.bmp        Prediction: bubble       Confidence: 99.0%
File: edge_733.bmp         Prediction: dent         Confidence: 95.3%
File: edge_4889.bmp        Prediction: bubble       Confidence: 70.1%
File: edge_3940.bmp        Prediction: foreignsub   Confidence: 92.5%
File: edge_4831.bmp        Prediction: bubble       Confidence: 60.9%
File: edge_4810.bmp        Prediction: bubble       Confidence: 63.6%
File: edge_4888.bmp        Prediction: bubble       Confidence: 55.8%
File: edge_5970.bmp        Prediction: bubble       Confidence: 100.0%
File: edge_971.bmp         Prediction: bubble       Confidence: 54.1%
File: edge_4927.bmp        Prediction: bubble       Confidence: 57.4%
File: edge_4925.bmp        Prediction: bubble       Confidence: 47.4%
File: edge_4912.bmp        Prediction: bubble       Confidence: 57.6%
File: edge_4868.bmp        Prediction: bubble       Confidence: 59.8%
File: edge_748.bmp         Prediction: torn         Confidence: 65.7%
File: edge_4897.bmp        Prediction: bubble       Confidence: 72.5%
File: edge_4876.bmp        Prediction: bubble       Confidence: 55.4%
File: edge_4816.bmp        Prediction: bubble       Confidence: 81.2%
File: edge_848.bmp         Prediction: torn         Confidence: 77.3%
File: edge_4871.bmp        Prediction: bubble       Confidence: 70.4%
File: edge_4838.bmp        Prediction: bubble       Confidence: 93.0%
File: edge_4903.bmp        Prediction: bubble       Confidence: 71.5%
File: edge_4886.bmp        Prediction: bubble       Confidence: 72.5%
File: edge_5020.bmp        Prediction: bubble       Confidence: 65.0%
File: edge_4864.bmp        Prediction: bubble       Confidence: 63.8%
File: edge_4377.bmp        Prediction: bubble       Confidence: 100.0%
File: edge_4878.bmp        Prediction: bubble       Confidence: 60.4%
File: edge_4322.bmp        Prediction: bubble       Confidence: 96.9%
File: edge_4885.bmp        Prediction: bubble       Confidence: 66.5%
File: edge_4898.bmp        Prediction: bubble       Confidence: 71.5%
File: edge_1755.bmp        Prediction: bubble       Confidence: 49.5%
File: edge_5021.bmp        Prediction: bubble       Confidence: 69.1%
File: edge_4343.bmp        Prediction: bubble       Confidence: 93.7%
File: edge_4822.bmp        Prediction: bubble       Confidence: 64.2%
File: edge_4058.bmp        Prediction: bubble       Confidence: 100.0%
File: edge_4345.bmp        Prediction: bubble       Confidence: 95.3%
File: edge_1094.bmp        Prediction: torn         Confidence: 73.8%
File: edge_4879.bmp        Prediction: foreignsub   Confidence: 50.1%
File: edge_4945.bmp        Prediction: bubble       Confidence: 55.4%
File: edge_4833.bmp        Prediction: bubble       Confidence: 60.4%
File: edge_4447.bmp        Prediction: dent         Confidence: 100.0%
File: edge_1102.bmp        Prediction: torn         Confidence: 100.0%
File: edge_4881.bmp        Prediction: bubble       Confidence: 56.3%
File: edge_4911.bmp        Prediction: bubble       Confidence: 56.5%
File: edge_4846.bmp        Prediction: bubble       Confidence: 60.5%
File: edge_719.bmp         Prediction: bubble       Confidence: 34.7%
File: edge_2659.bmp        Prediction: dent         Confidence: 81.2%
File: edge_4874.bmp        Prediction: bubble       Confidence: 82.1%
File: edge_1116.bmp        Prediction: torn         Confidence: 73.9%
File: edge_1164.bmp        Prediction: bubble       Confidence: 55.8%
File: edge_4491.bmp        Prediction: foreignsub   Confidence: 96.9%
File: edge_4922.bmp        Prediction: torn         Confidence: 43.4%
File: edge_4918.bmp        Prediction: bubble       Confidence: 81.9%
File: edge_2667.bmp        Prediction: bubble       Confidence: 100.0%
File: edge_887.bmp         Prediction: torn         Confidence: 78.6%
File: edge_4873.bmp        Prediction: torn         Confidence: 47.1%
File: edge_4938.bmp        Prediction: foreignsub   Confidence: 33.6%
File: edge_4877.bmp        Prediction: bubble       Confidence: 58.3%
File: edge_4870.bmp        Prediction: bubble       Confidence: 60.5%
File: edge_4837.bmp        Prediction: bubble       Confidence: 60.2%
File: edge_1148.bmp        Prediction: bubble       Confidence: 46.6%
File: edge_4683.bmp        Prediction: torn         Confidence: 96.7%
File: edge_756.bmp         Prediction: foreignsub   Confidence: 70.4%
File: edge_4883.bmp        Prediction: bubble       Confidence: 55.5%
File: edge_1140.bmp        Prediction: torn         Confidence: 99.9%
File: edge_973.bmp         Prediction: bubble       Confidence: 100.0%
File: edge_4828.bmp        Prediction: bubble       Confidence: 73.2%
File: edge_831.bmp         Prediction: bubble       Confidence: 84.9%
File: edge_4919.bmp        Prediction: bubble       Confidence: 54.2%
File: edge_1027.bmp        Prediction: dent         Confidence: 45.5%
File: edge_4829.bmp        Prediction: bubble       Confidence: 64.0%
File: edge_4887.bmp        Prediction: bubble       Confidence: 68.3%
File: edge_2642.bmp        Prediction: torn         Confidence: 94.7%
File: edge_4347.bmp        Prediction: bubble       Confidence: 96.8%
File: edge_2758.bmp        Prediction: torn         Confidence: 60.8%
File: edge_4926.bmp        Prediction: torn         Confidence: 49.2%
File: edge_4821.bmp        Prediction: torn         Confidence: 64.0%
File: edge_4830.bmp        Prediction: bubble       Confidence: 60.7%
File: edge_2759.bmp        Prediction: bubble       Confidence: 67.6%
File: edge_4856.bmp        Prediction: bubble       Confidence: 57.1%
File: edge_4954.bmp        Prediction: bubble       Confidence: 56.0%
File: edge_4439.bmp        Prediction: bubble       Confidence: 81.6%
File: edge_4849.bmp        Prediction: bubble       Confidence: 59.6%
File: edge_4915.bmp        Prediction: bubble       Confidence: 62.1%
File: edge_4814.bmp        Prediction: bubble       Confidence: 58.3%
File: edge_4823.bmp        Prediction: bubble       Confidence: 61.3%
File: edge_1500.bmp        Prediction: torn         Confidence: 70.5%
File: edge_4921.bmp        Prediction: bubble       Confidence: 61.9%
File: edge_778.bmp         Prediction: bubble       Confidence: 53.4%
File: edge_4847.bmp        Prediction: bubble       Confidence: 60.3%
File: edge_4818.bmp        Prediction: bubble       Confidence: 68.9%
File: edge_4853.bmp        Prediction: bubble       Confidence: 100.0%
File: edge_4896.bmp        Prediction: bubble       Confidence: 77.8%
File: edge_4948.bmp        Prediction: bubble       Confidence: 51.7%
File: edge_6070.bmp        Prediction: bubble       Confidence: 79.5%
File: edge_808.bmp         Prediction: bubble       Confidence: 62.2%
File: edge_4588.bmp        Prediction: bubble       Confidence: 100.0%
File: edge_4836.bmp        Prediction: bubble       Confidence: 85.6%
File: edge_1028.bmp        Prediction: torn         Confidence: 99.4%
File: edge_4852.bmp        Prediction: bubble       Confidence: 65.8%
File: edge_1179.bmp        Prediction: dent         Confidence: 55.6%
File: edge_4904.bmp        Prediction: bubble       Confidence: 60.3%
File: edge_734.bmp         Prediction: dent         Confidence: 97.7%
File: edge_4826.bmp        Prediction: bubble       Confidence: 64.0%
File: edge_883.bmp         Prediction: bubble       Confidence: 64.6%
File: edge_4910.bmp        Prediction: bubble       Confidence: 85.8%
File: edge_4895.bmp        Prediction: bubble       Confidence: 66.7%
File: edge_4854.bmp        Prediction: bubble       Confidence: 89.2%
File: edge_4869.bmp        Prediction: bubble       Confidence: 70.3%
File: edge_4612.bmp        Prediction: bubble       Confidence: 97.9%'''  # 전체 데이터를 여기에 넣어주세요

# Process each line
for line in data.strip().split('\n'):
    if line:  # 빈 줄 건너뛰기
        try:
            # Extract number from filename using regex and prediction
            number = re.search(r'edge_(\d+)\.bmp', line).group(1)
            prediction = line.split('Prediction:')[1].split('Confidence:')[0].strip()
            
            # Append to lists
            files.append(number)
            predictions.append(prediction)
        except AttributeError:
            print(f"Skipping problematic line: {line}")
            continue

# Create DataFrame
df = pd.DataFrame({
    'number': files,
    'prediction': predictions
})

# Save to CSV without index
df.to_csv('143+28_predictions.csv', index=False)

# Display first few rows without index
print("Data preview:")
print(df.to_string(index=False))

# %%
import os
import shutil

# 소스 폴더와 대상 폴더 경로
src_folder = '/home/ec2-user/SageMaker/data/NG'
dst_folder = '/home/ec2-user/SageMaker/data/NG_v2'

# 복사할 파일 리스트
files_to_copy = [
    '4483.bmp',
    '4306.bmp',
    '4383.bmp',
    '3940.bmp',
    '971.bmp',
    '4377.bmp',
    '4322.bmp',
    '4491.bmp',
    '2667.bmp',
    '4683.bmp',
    '2642.bmp',
    '4347.bmp',
    '4439.bmp',
    '4588.bmp',
    '883.bmp',
    '4612.bmp',
    '4362.bmp'
]

# 파일 복사
copied_count = 0
for filename in files_to_copy:
    src_path = os.path.join(src_folder, filename)
    dst_path = os.path.join(dst_folder, filename)
    if os.path.exists(src_path):
        shutil.copy2(src_path, dst_path)
        print(f"복사됨: {filename}")
        copied_count += 1
    else:
        print(f"파일을 찾을 수 없음: {filename}")

print(f"\n복사 완료! 총 {copied_count}개 파일이 복사되었습니다.")

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.semi_supervised import LabelPropagation
from sklearn.metrics.pairwise import rbf_kernel
import cv2
import math
from skimage.feature import graycomatrix, graycoprops
from sklearn.manifold import TSNE

def load_images_from_folder(folder_path):
    """폴더에서 이미지를 로드합니다."""
    images = []
    valid_extensions = ['.bmp', '.jpg', '.jpeg', '.png']
    
    for filename in os.listdir(folder_path):
        if any(filename.lower().endswith(ext) for ext in valid_extensions):
            image_path = os.path.join(folder_path, filename)
            img = cv2.imread(image_path)
            if img is not None:
                images.append({
                    'image': img,
                    'filename': filename
                })
    
    return images

def create_training_data(images, defect_images):
    """학습 데이터를 생성합니다."""
    features = []
    labels = []
    filenames = []
    categories = {'dent': 0, 'torn': 1, 'bubble': 2, 'foreignsub': 3}
    
    # 레이블이 있는 데이터와 없는 데이터 구분
    labeled_files = {d['file'].lower(): d['category'] for d in defect_images}
    
    labeled_count = 0
    for img_data in images:
        features.append(extract_features(img_data['image']))
        filenames.append(img_data['filename'])
        
        # 파일명을 소문자로 변환하여 비교
        if img_data['filename'].lower() in labeled_files:
            labels.append(categories[labeled_files[img_data['filename'].lower()]])
            labeled_count += 1
        else:
            labels.append(-1)
    
    print(f"Found {labeled_count} labeled images out of {len(images)} total images")
    
    if labeled_count == 0:
        raise ValueError("No labeled data found! Please check if the image filenames match with defect_images.")
    
    return np.array(features), np.array(labels), filenames

def extract_features(image):
    """특징 추출 함수"""
    features = []
    
    # 1. 엣지 검출 강화
    edges = cv2.Canny(image, 50, 150)
    edge_density = np.mean(edges) / 255.0
    
    # 2. 로컬 컨트라스트 특징
    local_std = np.std(image.astype(float))
    
    # 3. 텍스처 특징 추출
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY) if len(image.shape) == 3 else image
    glcm = graycomatrix(gray, [1], [0, np.pi/4, np.pi/2, 3*np.pi/4])
    contrast = graycoprops(glcm, 'contrast')[0]
    dissimilarity = graycoprops(glcm, 'dissimilarity')[0]
    
    # 4. 블롭 검출
    params = cv2.SimpleBlobDetector_Params()
    params.minThreshold = 10
    params.maxThreshold = 200
    params.filterByArea = True
    params.minArea = 20
    detector = cv2.SimpleBlobDetector_create(params)
    keypoints = detector.detect(gray)
    blob_count = len(keypoints)
    
    # 5. 엣지 방향성 분석
    sobelx = cv2.Sobel(gray, cv2.CV_64F, 1, 0, ksize=3)
    sobely = cv2.Sobel(gray, cv2.CV_64F, 0, 1, ksize=3)
    edge_angles = np.arctan2(sobely, sobelx)
    angle_hist, _ = np.histogram(edge_angles, bins=8, range=(-np.pi, np.pi))
    
    # 특징 벡터 구성
    features.extend([
        edge_density,
        local_std,
        *contrast,
        *dissimilarity,
        blob_count,
        *angle_hist
    ])
    
    return np.array(features)

def train_semi_supervised(features, labels):
    """반지도 학습 모델"""
    # 원본 feature 크기 저장
    original_size = len(features)
    
    # 데이터 증강
    augmented_features = []
    augmented_labels = []
    for i, (feat, label) in enumerate(zip(features, labels)):
        if label != -1:  # 레이블이 있는 데이터만 증강
            noise = np.random.normal(0, 0.1, feat.shape)
            augmented_features.append(feat + noise)
            augmented_labels.append(label)
    
    # 학습용 데이터 구성
    train_features = np.vstack([features, augmented_features])
    train_labels = np.concatenate([labels, augmented_labels])
    
    # 모델 파라미터 조정
    model = LabelPropagation(
        kernel='rbf',
        gamma=3,
        max_iter=2000,
        tol=1e-6
    )
    
    # 모델 학습
    model.fit(train_features, train_labels)
    
    # 원본 데이터에 대해서만 예측
    predictions = model.predict(features)
    probabilities = model.predict_proba(features)
    
    return predictions, probabilities

def compute_class_weights(labels):
    """클래스 불균형 처리를 위한 가중치 계산"""
    unique_labels = np.unique(labels[labels != -1])
    class_counts = np.array([np.sum(labels == label) for label in unique_labels])
    weights = 1.0 / class_counts
    weights = weights / np.sum(weights) * len(unique_labels)
    return dict(zip(unique_labels, weights))

def visualize_results(images, predictions, probabilities, filenames, original_folder_path='/home/ec2-user/SageMaker/sein/NG_2'):
    """불량품 탐지 결과 시각화"""
    # 카테고리 매핑
    categories = {0: 'dent', 1: 'torn', 2: 'bubble', 3:'foreignsub' }
    
    # 결과를 저장할 리스트
    results = []
    
    # 각 이미지에 대해 결과 시각화
    for idx, (image, pred, prob, filename) in enumerate(zip(images, predictions, probabilities, filenames)):
        if pred != -1:  # 예측된 이미지만 처리
            # 원본 이미지 경로 (edge_ 접두사 제거)
            original_filename = filename.replace('edge_', '')
            original_path = os.path.join(original_folder_path, original_filename)
            
            # 원본 이미지 로드
            original_img = cv2.imread(original_path)
            if original_img is None:
                print(f"Warning: Cannot load original image {original_filename}")
                continue
                
            # 결과 시각화를 위한 figure 생성
            plt.figure(figsize=(12, 6))
            
            # 원본 이미지 표시
            plt.subplot(1, 2, 1)
            plt.imshow(cv2.cvtColor(original_img, cv2.COLOR_BGR2RGB))
            plt.title('Original Image')
            plt.axis('off')
            
            # 엣지 처리된 이미지 표시
            plt.subplot(1, 2, 2)
            plt.imshow(cv2.cvtColor(image['image'], cv2.COLOR_BGR2RGB))
            
            # 예측 결과 및 확률 표시
            category = categories[pred]
            confidence = prob[pred] * 100
            plt.title(f'Detected: {category}\nConfidence: {confidence:.2f}%')
            plt.axis('off')
            
            # 결과 저장
            results.append({
                'filename': original_filename,
                'category': category,
                'confidence': confidence
            })
            
            plt.tight_layout()
            plt.show()
            plt.close()
            
            # 상세 정보 출력
            print(f"\nResults for {original_filename}:")
            print(f"Detected defect: {category}")
            print(f"Confidence: {confidence:.2f}%")
            print("-" * 50)
    
    return results

def main(edge_folder_path, original_folder_path, defect_images):
    """메인 실행 함수"""
    print("Loading images...")
    images = load_images_from_folder(edge_folder_path)
    
    print(f"Loaded {len(images)} images")
    print("\nImage filenames in folder:")
    for img in images[:5]:
        print(f"- {img['filename']}")
    
    print("\nLabeled images we're looking for:")
    for defect in defect_images:
        print(f"- {defect['file']} ({defect['category']})")
    
    print("\nExtracting features...")
    features, labels, filenames = create_training_data(images, defect_images)
    
    print("\nStandardizing features...")
    scaler = StandardScaler()
    scaled_features = scaler.fit_transform(features)
    
    print("Reducing dimensionality...")
    pca = PCA(n_components=min(20, scaled_features.shape[1]))
    reduced_features = pca.fit_transform(scaled_features)
    print(f"Reduced features shape: {reduced_features.shape}")
    
    print("\nTraining semi-supervised model...")
    predictions, probabilities = train_semi_supervised(reduced_features, labels)
    
    print("\nVisualizing results...")
    results = visualize_results(images, predictions, probabilities, filenames, original_folder_path)
    
    return results

if __name__ == "__main__":
    edge_folder_path = '/home/ec2-user/SageMaker/data/edge_NG_143_add_28'
    original_folder_path = '/home/ec2-user/SageMaker/data/NG_v2'
    
    defect_images = [
    # dent 예시 이미지들
    {'file': 'edge_830.bmp', 'category': 'dent'},
    {'file': 'edge_733.bmp', 'category': 'dent'},
    {'file': 'edge_4447.bmp', 'category': 'dent'},
    {'file': 'edge_2659.bmp', 'category': 'dent'},
    {'file': 'edge_725.bmp', 'category': 'dent'},
    {'file': 'edge_2675.bmp', 'category': 'dent'},
    
    # torn 예시 이미지들
    {'file': 'edge_997.bmp', 'category': 'torn'},
    {'file': 'edge_1102.bmp', 'category': 'torn'},
    {'file': 'edge_988.bmp', 'category': 'torn'},
    {'file': 'edge_856.bmp', 'category': 'torn'},
    {'file': 'edge_4987.bmp', 'category': 'torn'},
    {'file': 'edge_2642.bmp', 'category': 'torn'},
    {'file': 'edge_4683.bmp', 'category': 'torn'},
    
    # bubble 예시 이미지들
    {'file': 'edge_4748.bmp', 'category': 'bubble'},
    {'file': 'edge_4597.bmp', 'category': 'bubble'},
    {'file': 'edge_4588.bmp', 'category': 'bubble'},
    {'file': 'edge_4322.bmp', 'category': 'bubble'},
    {'file': 'edge_4377.bmp', 'category': 'bubble'},
    {'file': 'edge_4383.bmp', 'category': 'bubble'},
    {'file': 'edge_4345.bmp', 'category': 'bubble'},
    {'file': 'edge_4343.bmp', 'category': 'bubble'},
    {'file': 'edge_4612.bmp', 'category': 'bubble'},
    {'file': 'edge_4347.bmp', 'category': 'bubble'},
    {'file': 'edge_4362.bmp', 'category': 'bubble'},
    
    # foreignsub 예시 이미지들
    {'file': 'edge_3940.bmp', 'category': 'foreignsub'},
    {'file': 'edge_4306.bmp', 'category': 'foreignsub'},
    {'file': 'edge_4483.bmp', 'category': 'foreignsub'},
    {'file': 'edge_4491.bmp', 'category': 'foreignsub'},
]
    
    results = main(edge_folder_path, original_folder_path, defect_images)
